# %% [markdown]
# <div class="alert alert-info">
# Привет! Меня зовут Никита Мишин и я буду твоим ревьюером по этому проекты.
# Для простоты предлагаю общение на 'ты'. Буду предполагать, что ты не против:)
# Если более предпочтительно обращение на 'Вы', пиши, не стесняйся.
# Также если будут возникать вопросы, аналогично, пиши:)
#
# Предлагаю работать в известном тебе итеративном формате.
# Итерация состоит в моей проверке твоего решения.
# После решения могут остаться какие-то недочеты, которые я попрошу тебя устранить, ты их исправляешь и я проверяю твои решения.
#     Оставленные мною комментарии могут быть разного вида:
#
#     - зеленый: элегантные решения, которые тебе стоит запомнит и в дальнейшем взять на вооружение:)
#
#     - желтый: сигнал о том, что есть некритичная вещь(не всегда ошибка), что нужно точно поправить в следующей работе, даже желательно в этой (полезно, в первую очередь, для тебя:) ).Также это рекомендации на будущее
#
#     - красный: недочет, который нужно исправить в этой работе, для того, чтобы она была принята
#
#     - синий: полезная информация, доп ресурсы, "вопросы на подумать"
#
# Также попрошу не удалять мои комментарии:) <a class="tocSkip">
# </div>

# %% [markdown]
# |  |  |  |
# | ---: | :--- | :--- |
# | Курс:| Временные ряды | 14 |
# | Срок обучения на момент сдачи: | 5,5 месяцев |
#
# #  Прогнозирование заказов такси

# %% [markdown]
# Компания «Чётенькое такси» собрала исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час. Постройте модель для такого предсказания.
#
# Значение метрики *RMSE* на тестовой выборке должно быть не больше 48.
#
# Вам нужно:
#
# 1. Загрузить данные и выполнить их ресемплирование по одному часу.
# 2. Проанализировать данные.
# 3. Обучить разные модели с различными гиперпараметрами. Сделать тестовую выборку размером 10% от исходных данных.
# 4. Проверить данные на тестовой выборке и сделать выводы.
#
#
# Данные лежат в файле `taxi.csv`. Количество заказов находится в столбце `num_orders` (от англ. *number of orders*, «число заказов»).

# %% [markdown]
# ## Подготовка

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import datetime

from IPython.display import display
#from scipy import stats as st

from sklearn.preprocessing import StandardScaler 
from sklearn.utils import shuffle
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV, KFold, cross_val_score, train_test_split
from sklearn.tree import DecisionTreeRegressor #,DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestRegressor #,RandomForestClassifier
from sklearn.linear_model import LinearRegression #,LogisticRegression 
from sklearn.dummy import DummyRegressor#, DummyClassifier
from sklearn.metrics import mean_squared_error#, make_scorer, mean_absolute_error, r2_score, accuracy_score, f1_score, confusion_matrix, roc_auc_score

from catboost import CatBoostRegressor #,CatBoostClassifier

from lightgbm import LGBMRegressor #,LGBMClassifier

# %%
def make_features(data, target, max_lag, rolling_mean_size):
    '''
    Получает data с временнЫм индексом и целевой признак, 
    max_lag - глубина отстающих значений, 
    rolling_mean_size - размер выборки для скользящего среднего
    
    Создает признаки в df с "временнЫм" индексом
    Первая часть выделяет "календарные признаки" (год/месяц/день...)
    Вторая добавляет «отстающие значения»
    Третья добавляет "скользящее среднее"
    '''
    
#    data['year'] = data.index.year
    data['month'] = data.index.month
    data['day'] = data.index.day
    data['hour'] = data.index.hour
    data['dayofweek'] = data.index.dayofweek
    
    for lag in range(1, max_lag + 1):
        data['lag_{}'.format(lag)] = data[target].shift(lag)

    data['rolling_mean'] = data[target].shift().rolling(rolling_mean_size).mean()

# %% [markdown]
# <div class="alert alert-success">
# <h1>Комментарий ревьюера <a class="tocSkip"></a></h1>
# круто, что оформил построение фич в отдельную функцию
# </div>

# %%
data = pd.read_csv('https://code.s3.yandex.net/datasets/taxi.csv', index_col=[0], parse_dates=[0])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
# num_orders    26496 non-null int64
# dtypes: int64(1)
# memory usage: 414.0 KB

# %%
data.index.name = None

# %%
display(data.head(5))
# Out:
#                      num_orders
# 2018-03-01 00:00:00           9
# 2018-03-01 00:10:00          14
# 2018-03-01 00:20:00          28
# 2018-03-01 00:30:00          20
# 2018-03-01 00:40:00          32

# %%
data.sort_index(inplace=True)

# %% [markdown]
# <div class="alert alert-success">
# <h1>Комментарий ревьюера <a class="tocSkip"></a></h1>
# Круто, что не забыл отсортировать временной ряд
# </div>

# %%
data['num_orders'].describe()
# Out:
# count    26496.000000
# mean        14.070463
# std          9.211330
# min          0.000000
# 25%          8.000000
# 50%         13.000000
# 75%         19.000000
# max        119.000000
# Name: num_orders, dtype: float64

# %%
data['num_orders'].plot.hist(bins=100, edgecolor = 'black', figsize=(14, 6), grid=True, color='gold')
plt.title('Распределение спроса'); 
plt.ylabel('Количество строк (по 10 минут), шт.')
plt.xlabel('Количество заказов, шт.');

# %%
fig, ax = plt.subplots()
ax.scatter(data.index, data, s=1)
fig.set_figwidth(14)
fig.set_figheight(10)
plt.show()

# %%
data = data.resample('1h').sum()

# %%
fig, ax = plt.subplots()
ax.scatter(data.index, data, s=1)
fig.set_figwidth(14)
fig.set_figheight(6)
plt.show()

# %%
#display(data.head(5))

# %%
make_features(data, 'num_orders', 6, 12)

# %% [markdown]
# <div class="alert alert-info">
# <h1>Комментарий ревьюера <a class="tocSkip"></a></h1>
# Хм, а чем обусловлен выбор 6 и 12? Хотелось бы пояснения;)
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h1>Ответ студента <a class="tocSkip"></a></h1>
# rolling_mean - считает значение за пол-дня, а 6 дополнительных столбцов lag показалось достаточно.  </div>

# %%
display(data.head(5))
# Out:
#                      num_orders  month  day  hour  dayofweek  lag_1  lag_2  \
# 2018-03-01 00:00:00         124      3    1     0          3    NaN    NaN
# 2018-03-01 01:00:00          85      3    1     1          3  124.0    NaN
# 2018-03-01 02:00:00          71      3    1     2          3   85.0  124.0
# 2018-03-01 03:00:00          66      3    1     3          3   71.0   85.0
# 2018-03-01 04:00:00          43      3    1     4          3   66.0   71.0
#
#                      lag_3  lag_4  lag_5  lag_6  rolling_mean
# 2018-03-01 00:00:00    NaN    NaN    NaN    NaN           NaN
# 2018-03-01 01:00:00    NaN    NaN    NaN    NaN           NaN
# 2018-03-01 02:00:00    NaN    NaN    NaN    NaN           NaN
# 2018-03-01 03:00:00  124.0    NaN    NaN    NaN           NaN
# 2018-03-01 04:00:00   85.0  124.0    NaN    NaN           NaN

# %% [markdown]
# ## Анализ

# %%
data['num_orders'].describe()
# Out:
# count    4416.000000
# mean       84.422781
# std        45.023853
# min         0.000000
# 25%        54.000000
# 50%        78.000000
# 75%       107.000000
# max       462.000000
# Name: num_orders, dtype: float64

# %%
data['num_orders'].plot.hist(bins=100, edgecolor = 'black', figsize=(14, 6), grid=True, color='gold')
plt.title('Распределение спроса'); 
plt.ylabel('Количество строк (часов), шт.')
plt.xlabel('Количество заказов, шт.');

# %%
data['num_orders'].quantile(0.999)
# Out:
# 289.1900000000005

# %%
data.loc['2018-05-01':'2018-05-14', ['num_orders', 'rolling_mean']].plot(figsize=(14, 6))
plt.title('График изменения спроса (фрагмент с 01.05.18 по 14.05.18)'); 
plt.ylabel('Количество заказов, шт.')
plt.xlabel('Дата/время')
plt.legend(['спрос', 'скользящее среднее']);

# %%
data.resample('1D').sum().loc[:, ['num_orders']].plot(figsize=(14, 6))
plt.title('График изменения спроса (по дням)'); 
plt.ylabel('Количество заказов, шт.')
plt.xlabel('Дата')
plt.legend(['спрос']);

# %%
fig, ax = plt.subplots(figsize=(14,6))
sns.heatmap(data.corr(), annot = True, vmin=-1, vmax=1, center= 0, cmap= 'coolwarm', fmt='.2g');

# %% [markdown]
# За 6 месяцев прослеживается тренд на рост количества заказов.
#
# В августе присутствуют "пиковые" значения спроса и заметно ускорение прироста заказов.
#
# На графике видны "дневные" закономерности (рост спроса вечером/в начале ночи, спад к середине ночи и средний уровень днем)

# %% [markdown]
# <div class="alert alert-success">
# <h1>Комментарий ревьюера <a class="tocSkip"></a></h1>
# Все верно, смог увидеть тренды и сезонность в данных. Можно было рассмотреть промежуток в 24 часа, чтобы детальные указать пики по заказам
# </div>

# %% [markdown]
# ## Обучение и тестирование

# %%
features_train, features_test, target_train, target_test = train_test_split(
    data.drop(['num_orders'], axis=1), 
    data['num_orders'], 
    test_size=0.1, shuffle=False)

# %%
features_train = features_train.dropna()
target_train = target_train[features_train.index]

# %%
time_split = TimeSeriesSplit(n_splits=10)

# %% [markdown]
# ### Линейная регрессия

# %%
model_1 = LinearRegression()

model_1.fit(features_train, target_train)
model_1.rmse = mean_squared_error(target_test, model_1.predict(features_test))**0.5
model_1.name = 'LinearRegression'

print (model_1.name, model_1.rmse)
# Out:
# LinearRegression 52.7394256195106

# %% [markdown]
# <div class="alert alert-info">
# <h1>Исправлено <a class="tocSkip"></a></h1>
# В местном юпитере видимо не последние версии библиотек - поэтому при вычичлении метрики поменял mean_squared_error (squared=false) на mean_squared_error squared**0.5.
# </div>

# %% [markdown]
# ### Дерево решений

# %%
model_2 = DecisionTreeRegressor()

parametrs = { 'max_depth': [None, 24, 32],
              'max_features' : ["auto", "sqrt", "log2", None],
              'min_samples_split': [2, 10, 50, 100]}

grid = GridSearchCV(model_2, parametrs, scoring='neg_mean_absolute_error', cv=time_split)
grid.fit(features_train, target_train)
params = grid.best_params_
model_2 = DecisionTreeRegressor().set_params(**params)
model_2.fit(features_train, target_train)
model_2.rmse = mean_squared_error(target_test, model_2.predict(features_test))**0.5
model_2.name = 'DecisionTreeRegressor'

print (model_2.name, model_2.rmse, params)
# Out:
# DecisionTreeRegressor 49.09266259041065 {'max_depth': None, 'max_features': 'auto', 'min_samples_split': 50}

# %% [markdown]
# <div class="alert alert-danger">
# <h1>Комментарий ревьюера <a class="tocSkip"></a></h1>
# Смотри, обычная кросс-валидация тут не пройдет, потому что рано или поздно у нас произодйте так, что мы будет предсказывать для прошлого.
#
# Подсказа <a href='https://www.kaggle.com/kashnitsky/correct-time-aware-cross-validation-scheme'> ссылка</a>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h1>Исправлено <a class="tocSkip"></a></h1>
# Ой, думал что по умолчанию (cv default=None) в grid не реализована кросс-валидация. Спасибо, посмотрел.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h1>Комментарий ревьюера v2 <a class="tocSkip"></a></h1>
# Теперь гут:)</div>

# %% [markdown]
# ### Случайный лес

# %%
model_3 = RandomForestRegressor()

parametrs = { 'n_estimators': [12, 15, 18],
#              'max_features' : ["auto", "sqrt", "log2"],
              'min_samples_split': [2, 10, 50], 
              'max_depth': [None]}

grid = GridSearchCV(model_3, parametrs, scoring='neg_mean_absolute_error', cv=time_split)
grid.fit(features_train, target_train)
params = grid.best_params_
#model_3 = DecisionTreeRegressor().set_params(**params)
model_3.fit(features_train, target_train)
model_3.rmse = mean_squared_error(target_test, model_3.predict(features_test))**0.5
model_3.name = 'RandomForestRegressor'

print (model_3.name, model_3.rmse, params)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor 44.14604669632409 {'max_depth': None, 'min_samples_split': 10, 'n_estimators': 18}

# %% [markdown]
# ### LightGBM

# %%
model_4 = LGBMRegressor()

parametrs = { 'metric': ['rmse'],
              'boosting_type': ['gbdt'], #, 'dart']
              'n_estimators': [90, 100, 110],
              'max_depth': [-1, 17, 18, 19] }

grid = GridSearchCV(model_4, parametrs, scoring='neg_mean_absolute_error', cv=time_split)
grid.fit(features_train, target_train)
params = grid.best_params_
model_4 = LGBMRegressor().set_params(**params)
model_4.fit(features_train, target_train)
model_4.rmse = mean_squared_error(target_test, model_4.predict(features_test))**0.5
model_4.name = 'LGBMRegressor'

print (model_4.name, model_4.rmse, params)
# Out:
# LGBMRegressor 43.912680335551464 {'boosting_type': 'gbdt', 'max_depth': 19, 'metric': 'rmse', 'n_estimators': 90}

# %% [markdown]
# ### Dummy

# %% [markdown]
# Т.к. тренд "на рост" наиболее точная константа будет около верхних значений.

# %%
for quant in [0.91, 0.92, 0.93, 0.94, 0.95]:
    model_5 = DummyRegressor(strategy = 'quantile', quantile=quant)
    model_5.fit(features_train, target_train)
    model_5.rmse = mean_squared_error(target_test, model_5.predict(features_test))**0.5
    print(quant, model_5.rmse)
# Out:
# 0.91 59.32440151728979
# 0.92 58.81268678352344
# 0.93 58.570296550461904
# 0.94 58.650780277412515
# 0.95 59.155290687220806

# %%
model_list = [model_1, model_2, model_3, model_4]
for model in model_list:
    print('rmse: %.1f' %model.rmse, '  Модель:', model.name)
# Out:
# rmse: 52.7   Модель: LinearRegression
# rmse: 49.1   Модель: DecisionTreeRegressor
# rmse: 44.1   Модель: RandomForestRegressor
# rmse: 43.9   Модель: LGBMRegressor

# %% [markdown]
# <div class="alert alert-info">
# <h1>Комментарий ревьюера <a class="tocSkip"></a></h1>
# Для сравнения стоило реализовать дамми модель (которая предсказывает предыдущее значение)</div>

# %% [markdown]
# <div class="alert alert-info">
# <h1>Готово <a class="tocSkip"></a></h1>
# Последнее значение трейн брать не стал т.к. может быть сдвинуто от лучшей константы. Перебрал несколько верхних квантилей. Получил довольно неплохие значения RMSE (58-59). С учетом изменяющегося на тестовом участке тренда для нового набора данных 0,93 квантиль возможно не даст лучшее значение константной модели.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h1>Комментарий ревьюера v2 <a class="tocSkip"></a></h1>
# Спасибо за доработку проекта! Удачи в следующих проектах!</div>

# %% [markdown]
# <div class="alert alert-success">
# <h1>Комментарий ревьюера <a class="tocSkip"></a></h1>
# Круто, что опробовал разные модели, бейзлайн успешно побит! Поздравляю!</div>

# %% [markdown]
# Из рассмотренных моделей наиболее точные предсказания дает RandomForestRegressor.
# В рамки заданного RMSE (48) укладывается также LGBMRegressor.

# %% [markdown]
# <div class="alert alert-success">
# <h1>Комментарий ревьюера <a class="tocSkip"></a></h1>
# Оставил подсказки, где закралась ошибка:):
#
#     - кросс-валидация
#
# Будут вопросы, пиши:)
#
# По общему впечатлению:
#
#     - код написан хорошо
#
#     - соблюдена структура проекта
#
#     - оставил пару советов
#
#
# </div>

# %% [markdown]
# ## Чек-лист проверки

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Данные загружены и подготовлены
# - [x]  Данные проанализированы
# - [x]  Модель обучена, гиперпараметры подобраны
# - [x]  Качество моделей проверено, выводы сделаны
# - [x]  Значение *RMSE* на тестовой выборке не больше 48
