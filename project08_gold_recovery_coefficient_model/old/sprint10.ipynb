# %% [markdown]
# <div class="alert alert-success">
#     Hi! I'm glad to say that you project has been accepted and now you can move on to the next sprint! Keep up the good work!
# </div>

# %% [markdown]
# # Review
# Hi, my name is Dmitry and I will be reviewing your project.
#
# You can find my comments in colored markdown cells:
#
# <div class="alert alert-success">
#     If everything is done succesfully.
# </div>
#
# <div class="alert alert-info">
#     If I have some (optional) suggestions, or questions to think about, or general comments.
# </div>
#
# <div class="alert alert-danger">
#     If a section requires some corrections. Work can't be accepted with red comments.
# </div>
#
# First of all, thank you for turning in the project! While there is room for improvement, on the whole your project is looking pretty good. There are a couple of problems that need to be fixed, but don't worry! You've got this!

# %% [markdown]
# >Hi! Great, thanks!

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import *
from sklearn.ensemble import *
from sklearn.tree import *
from sklearn.linear_model import *
from sklearn.metrics import *
from sklearn.utils import shuffle
from sklearn.dummy import DummyRegressor

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import random
random_state=42
random.seed(random_state)
np.random.seed(random_state)

import warnings
warnings.filterwarnings('ignore')
import logging
logger = logging.getLogger()
logger.setLevel(logging.CRITICAL)

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %% [markdown]
# <div class="markdown markdown_size_normal markdown_type_theory"><h1>Project description</h1><div class="paragraph">The data is stored in three files:</div><ul><li><code class="code-inline code-inline_theme_light">gold_recovery_train.csv</code> — training dataset d<a href="https://code.s3.yandex.net/datasets/gold_recovery_train.csv">ownload</a></li><li><code class="code-inline code-inline_theme_light">gold_recovery_test.csv</code> — test dataset <a href="https://code.s3.yandex.net/datasets/gold_recovery_test.csv">download</a></li><li><code class="code-inline code-inline_theme_light">gold_recovery_full.csv</code> — source dataset <a href="https://code.s3.yandex.net/datasets/gold_recovery_full.csv">download</a></li></ul><div class="paragraph">Data is indexed with the date and time of acquisition (<code class="code-inline code-inline_theme_light">date</code> feature). Parameters that are next to each other in terms of time are often similar.</div><div class="paragraph">Some parameters are not available because they were measured and/or calculated much later. That's why, some of the features that are present in the training set may be absent from the test set. The test set also doesn't contain targets.</div><div class="paragraph">The source dataset contains the training and test sets with all the features.</div><div class="paragraph">You have the raw data that was only downloaded from the warehouse. Before building the model, check the correctness of the data. For that, use our instructions.</div>

# %% [markdown]
# <h2>Data description</h2><div class="paragraph"><strong>Technological process</strong></div><ul><li><em>Rougher feed</em> — raw material</li><li><em>Rougher additions</em> (or <em>reagent additions</em>) — flotation reagents: <em>Xanthate, Sulphate, Depressant</em>
#   <ul><li><em>Xanthate</em> — promoter or flotation activator;</li><li><em>Sulphate</em> — sodium sulphide for this particular process;</li><li><em>Depressant</em> — sodium silicate.</li></ul></li><li><em>Rougher process</em>  — flotation</li><li><em>Rougher tails</em> — product residues</li><li><em>Float banks</em> — flotation unit</li><li><em>Cleaner process</em> — purification</li><li><em>Rougher Au</em> — rougher gold concentrate</li><li><em>Final Au</em> — final gold concentrate</li></ul><div class="paragraph"><strong>Parameters of stages</strong></div><ul><li><em>air amount — volume of air</em></li><li><em>fluid levels</em></li><li><em>feed size</em> — feed particle size</li><li><em>feed rate</em></li></ul><h2>Feature naming</h2><div class="paragraph">Here's how you name the features:</div><div class="paragraph"><code class="code-inline code-inline_theme_light">[stage].[parameter_type].[parameter_name]</code></div><div class="paragraph">Example: <code class="code-inline code-inline_theme_light">rougher.input.feed_ag</code></div><div class="paragraph">Possible values for <code class="code-inline code-inline_theme_light">[stage]</code>:</div><ul><li><em>rougher —</em> flotation</li><li><em>primary_cleaner</em> — primary purification</li><li><em>secondary_cleaner</em> — secondary purification</li><li><em>final</em> — final characteristics</li></ul><div class="paragraph">Possible values for <code class="code-inline code-inline_theme_light">[parameter_type]</code>:</div><ul><li><em>input</em> — raw material parameters</li><li><em>output</em> — product parameters</li><li><em>state</em> — parameters characterizing the current state of the stage</li><li><em>calculation —</em> calculation characteristics</li></ul>

# %%
def display_group_density_plot(df, groupby, on, palette = None, figsize = None, title="", ax=None): 
    """
    Displays a density plot by group, given a continuous variable, and a group to split the data by
    :param df: DataFrame to display data from
    :param groupby: Column name by which plots would be grouped (Categorical, maximum 10 categories)
    :param on: Column name of the different density plots
    :param palette: Color palette to use for drawing
    :param figsize: Figure size
    :return: matplotlib.axes._subplots.AxesSubplot object
    """
    if palette is None:
      palette = sns.color_palette('Set2')
    if figsize is None:
      figsize = (10, 5)
    if not isinstance(df, pd.core.frame.DataFrame):
        raise ValueError('df must be a pandas DataFrame')

    if not groupby:
        raise ValueError('groupby parameter must be provided')

    elif not groupby in df.keys():
        raise ValueError(groupby + ' column does not exist in the given DataFrame')

    if not on:
        raise ValueError('on parameter must be provided')

    elif not on in df.keys():
        raise ValueError(on + ' column does not exist in the given DataFrame')

    if len(set(df[groupby])) > 10:
        groups = df[groupby].value_counts().index[:10]

    else:
        groups = set(df[groupby])

    # Get relevant palette
    if palette:
        palette = palette[:len(groups)]
    else:
        palette = sns.color_palette()[:len(groups)]

    if ax is None:
      fig = plt.figure(figsize=figsize)
      ax = fig.add_subplot(111)
    
    ax.legend(bbox_to_anchor=(1.04, 1), loc='upper left')
    for value, color in zip(groups, palette):
        sns.kdeplot(df.loc[df[groupby] == value][on], \
                    shade=True, color=color, label=value, ax=ax)
    if not title:
      title = str("Distribution of " + on + " per " + groupby + " group")
    
    ax.set_title(title,fontsize=16)
    ax.set_xlabel(on, fontsize=16)
    return ax

# %%
#missing value ratio
def missing_values(df):
    df_nulls=pd.concat([df.dtypes, df.isna().sum(), df.isna().sum()/len(df)], axis=1)
    df_nulls.columns = ["type","count","missing_ratio"]
    df_nulls=df_nulls[df_nulls["count"]>0]
    df_nulls.sort_values(by="missing_ratio", ascending=False)
    return df_nulls

#outliers by 3 sigma rule
def outlier(data):
    data_mean, data_std = np.mean(data), np.std(data)
    cut_off = data_std * 3
    lower, upper = data_mean - cut_off, data_mean + cut_off
    outliers = [x for x in data if x < lower or x > upper]
    outliers_removed = [x for x in data if x >= lower and x <= upper]
    return len(outliers)

# full description statistics 
def describe_full(df, target_name=""):
    data_describe = df.describe().T
    df_numeric = df._get_numeric_data()
    if target_name in df.columns:
        corr_with_target=df_numeric.drop(target_name, axis=1).apply(lambda x: x.corr(df_numeric[target_name]))
        data_describe['corr_with_target']=corr_with_target
    dtype_df = df_numeric.dtypes
    data_describe['dtypes'] = dtype_df
    data_null = df_numeric.isnull().sum()/len(df) * 100
    data_describe['Missing %'] = data_null
    Cardinality = df_numeric.apply(pd.Series.nunique)
    data_describe['Cardinality'] = Cardinality
    df_skew = df_numeric.skew(axis=0, skipna=True)
    data_describe['Skew'] = df_skew
    data_describe['outliers']=[outlier(df_numeric[col]) for col in df_numeric.columns]
    data_describe['kurtosis']=df_numeric.kurtosis()
    return data_describe

# %% [markdown]
# 1. Prepare the data

# %% [markdown]
# 1.1. Open the files and look into the data.
# Path to files:
# * /datasets/gold_recovery_train.csv
# * /datasets/gold_recovery_test.csv
# * /datasets/gold_recovery_full.csv

# %%
df_train = pd.read_csv("https://code.s3.yandex.net/datasets/gold_recovery_train.csv")
df_test = pd.read_csv("https://code.s3.yandex.net/datasets/gold_recovery_test.csv")
df_full = pd.read_csv("https://code.s3.yandex.net/datasets/gold_recovery_full.csv")

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22716 entries, 0 to 22715
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                22716 non-null  object
#  1   final.output.concentrate_ag                         22627 non-null  float64
#  2   final.output.concentrate_pb                         22629 non-null  float64
#  3   final.output.concentrate_sol                        22331 non-null  float64
#  4   final.output.concentrate_au                         22630 non-null  float64
#  5   final.output.recovery                               20753 non-null  float64
#  6   final.output.tail_ag                                22633 non-null  float64
#  7   final.output.tail_pb                                22516 non-null  float64
#  8   final.output.tail_sol                               22445 non-null  float64
#  9   final.output.tail_au                                22635 non-null  float64
#  10  primary_cleaner.input.sulfate                       21107 non-null  float64
#  11  primary_cleaner.input.depressant                    21170 non-null  float64
#  12  primary_cleaner.input.feed_size                     22716 non-null  float64
#  13  primary_cleaner.input.xanthate                      21565 non-null  float64
#  14  primary_cleaner.output.concentrate_ag               22618 non-null  float64
#  15  primary_cleaner.output.concentrate_pb               22268 non-null  float64
#  16  primary_cleaner.output.concentrate_sol              21918 non-null  float64
#  17  primary_cleaner.output.concentrate_au               22618 non-null  float64
#  18  primary_cleaner.output.tail_ag                      22614 non-null  float64
#  19  primary_cleaner.output.tail_pb                      22594 non-null  float64
#  20  primary_cleaner.output.tail_sol                     22365 non-null  float64
#  21  primary_cleaner.output.tail_au                      22617 non-null  float64
#  22  primary_cleaner.state.floatbank8_a_air              22660 non-null  float64
#  23  primary_cleaner.state.floatbank8_a_level            22667 non-null  float64
#  24  primary_cleaner.state.floatbank8_b_air              22660 non-null  float64
#  25  primary_cleaner.state.floatbank8_b_level            22673 non-null  float64
#  26  primary_cleaner.state.floatbank8_c_air              22662 non-null  float64
#  27  primary_cleaner.state.floatbank8_c_level            22673 non-null  float64
#  28  primary_cleaner.state.floatbank8_d_air              22661 non-null  float64
#  29  primary_cleaner.state.floatbank8_d_level            22673 non-null  float64
#  30  rougher.calculation.sulfate_to_au_concentrate       22672 non-null  float64
#  31  rougher.calculation.floatbank10_sulfate_to_au_feed  22672 non-null  float64
#  32  rougher.calculation.floatbank11_sulfate_to_au_feed  22672 non-null  float64
#  33  rougher.calculation.au_pb_ratio                     21089 non-null  float64
#  34  rougher.input.feed_ag                               22618 non-null  float64
#  35  rougher.input.feed_pb                               22472 non-null  float64
#  36  rougher.input.feed_rate                             22163 non-null  float64
#  37  rougher.input.feed_size                             22277 non-null  float64
#  38  rougher.input.feed_sol                              22357 non-null  float64
#  39  rougher.input.feed_au                               22617 non-null  float64
#  40  rougher.input.floatbank10_sulfate                   21415 non-null  float64
#  41  rougher.input.floatbank10_xanthate                  22247 non-null  float64
#  42  rougher.input.floatbank11_sulfate                   22038 non-null  float64
#  43  rougher.input.floatbank11_xanthate                  20459 non-null  float64
#  44  rougher.output.concentrate_ag                       22618 non-null  float64
#  45  rougher.output.concentrate_pb                       22618 non-null  float64
#  46  rougher.output.concentrate_sol                      22526 non-null  float64
#  47  rougher.output.concentrate_au                       22618 non-null  float64
#  48  rougher.output.recovery                             19597 non-null  float64
#  49  rougher.output.tail_ag                              19979 non-null  float64
#  50  rougher.output.tail_pb                              22618 non-null  float64
#  51  rougher.output.tail_sol                             19980 non-null  float64
#  52  rougher.output.tail_au                              19980 non-null  float64
#  53  rougher.state.floatbank10_a_air                     22646 non-null  float64
#  54  rougher.state.floatbank10_a_level                   22647 non-null  float64
#  55  rougher.state.floatbank10_b_air                     22646 non-null  float64
#  56  rougher.state.floatbank10_b_level                   22647 non-null  float64
#  57  rougher.state.floatbank10_c_air                     22646 non-null  float64
#  58  rougher.state.floatbank10_c_level                   22654 non-null  float64
#  59  rougher.state.floatbank10_d_air                     22641 non-null  float64
#  60  rougher.state.floatbank10_d_level                   22649 non-null  float64
#  61  rougher.state.floatbank10_e_air                     22096 non-null  float64
#  62  rougher.state.floatbank10_e_level                   22649 non-null  float64
#  63  rougher.state.floatbank10_f_air                     22641 non-null  float64
#  64  rougher.state.floatbank10_f_level                   22642 non-null  float64
#  65  secondary_cleaner.output.tail_ag                    22616 non-null  float64
#  66  secondary_cleaner.output.tail_pb                    22600 non-null  float64
#  67  secondary_cleaner.output.tail_sol                   20501 non-null  float64
#  68  secondary_cleaner.output.tail_au                    22618 non-null  float64
#  69  secondary_cleaner.state.floatbank2_a_air            22333 non-null  float64
#  70  secondary_cleaner.state.floatbank2_a_level          22591 non-null  float64
#  71  secondary_cleaner.state.floatbank2_b_air            22538 non-null  float64
#  72  secondary_cleaner.state.floatbank2_b_level          22588 non-null  float64
#  73  secondary_cleaner.state.floatbank3_a_air            22585 non-null  float64
#  74  secondary_cleaner.state.floatbank3_a_level          22587 non-null  float64
#  75  secondary_cleaner.state.floatbank3_b_air            22592 non-null  float64
#  76  secondary_cleaner.state.floatbank3_b_level          22590 non-null  float64
#  77  secondary_cleaner.state.floatbank4_a_air            22571 non-null  float64
#  78  secondary_cleaner.state.floatbank4_a_level          22587 non-null  float64
#  79  secondary_cleaner.state.floatbank4_b_air            22608 non-null  float64
#  80  secondary_cleaner.state.floatbank4_b_level          22607 non-null  float64
#  81  secondary_cleaner.state.floatbank5_a_air            22615 non-null  float64
#  82  secondary_cleaner.state.floatbank5_a_level          22615 non-null  float64
#  83  secondary_cleaner.state.floatbank5_b_air            22615 non-null  float64
#  84  secondary_cleaner.state.floatbank5_b_level          22616 non-null  float64
#  85  secondary_cleaner.state.floatbank6_a_air            22597 non-null  float64
#  86  secondary_cleaner.state.floatbank6_a_level          22615 non-null  float64
# dtypes: float64(86), object(1)
# memory usage: 15.1+ MB

# %% [markdown]
# 1.2. Check that recovery is calculated correctly. Using the training set, calculate recovery for the rougher.output.recovery feature. Find the MAE between your calculations and the feature values. Provide findings.

# %%
list(filter(lambda s:"rougher" in s,df_train.columns))
# Out:
# ['rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.input.feed_ag',
#  'rougher.input.feed_pb',
#  'rougher.input.feed_rate',
#  'rougher.input.feed_size',
#  'rougher.input.feed_sol',
#  'rougher.input.feed_au',
#  'rougher.input.floatbank10_sulfate',
#  'rougher.input.floatbank10_xanthate',
#  'rougher.input.floatbank11_sulfate',
#  'rougher.input.floatbank11_xanthate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.concentrate_au',
#  'rougher.output.recovery',
#  'rougher.output.tail_ag',
#  'rougher.output.tail_pb',
#  'rougher.output.tail_sol',
#  'rougher.output.tail_au',
#  'rougher.state.floatbank10_a_air',
#  'rougher.state.floatbank10_a_level',
#  'rougher.state.floatbank10_b_air',
#  'rougher.state.floatbank10_b_level',
#  'rougher.state.floatbank10_c_air',
#  'rougher.state.floatbank10_c_level',
#  'rougher.state.floatbank10_d_air',
#  'rougher.state.floatbank10_d_level',
#  'rougher.state.floatbank10_e_air',
#  'rougher.state.floatbank10_e_level',
#  'rougher.state.floatbank10_f_air',
#  'rougher.state.floatbank10_f_level']

# %%
rougher_output_recovery_calc = 100 * (df_train['rougher.output.concentrate_au'] * (df_train['rougher.input.feed_au'] - df_train['rougher.output.tail_au'])) / (df_train['rougher.input.feed_au'] * (df_train['rougher.output.concentrate_au'] - df_train['rougher.output.tail_au']))
df_output_rougher = pd.DataFrame({"output_recovery":df_train["rougher.output.recovery"],"calc":rougher_output_recovery_calc}).dropna()
MAE = mean_absolute_error(df_output_rougher["output_recovery"],df_output_rougher["calc"])
print(f"MAE={MAE}")
del df_output_rougher
# Out:
# MAE=1.0898633667227423e-14

# %% [markdown]
# as we could see, result is correct

# %% [markdown]
# <div class="alert alert-success">
#     Good job checking the recovery data validity!
# </div>

# %% [markdown]
# 1.3. Analyze the features not available in the test set. What are these parameters? What is their type?

# %%
df_types = df_full.dtypes.reset_index()
df_types.columns = ["name", "type"]
all_columns = pd.Series(list(set(df_full.columns).union(set(df_train.columns).union(set(df_test.columns)))))
df_temp = pd.DataFrame({"name": all_columns}).merge(df_types).sort_values(by="name")
df_temp["full"] = np.vectorize(lambda x: int(x in df_full.columns))(df_temp["name"].values)
df_temp["train"] = np.vectorize(lambda x: int(x in df_train.columns))(df_temp["name"].values)
df_temp["test"] = np.vectorize(lambda x: int(x in df_test.columns))(df_temp["name"].values)
df_temp[df_temp["test"]==0]
# Out:
#                                                  name     type  full  train  \
# 70                        final.output.concentrate_ag  float64     1      1
# 42                        final.output.concentrate_au  float64     1      1
# 86                        final.output.concentrate_pb  float64     1      1
# 83                       final.output.concentrate_sol  float64     1      1
# 75                              final.output.recovery  float64     1      1
# 36                               final.output.tail_ag  float64     1      1
# 35                               final.output.tail_au  float64     1      1
# 54                               final.output.tail_pb  float64     1      1
# 21                              final.output.tail_sol  float64     1      1
# 19              primary_cleaner.output.concentrate_ag  float64     1      1
# 11              primary_cleaner.output.concentrate_au  float64     1      1
# 49              primary_cleaner.output.concentrate_pb  float64     1      1
# 53             primary_cleaner.output.concentrate_sol  float64     1      1
# 76                     primary_cleaner.output.tail_ag  float64     1      1
# 25                     primary_cleaner.output.tail_au  float64     1      1
# 60                     primary_cleaner.output.tail_pb  float64     1      1
# 13                    primary_cleaner.output.tail_sol  float64     1      1
# 47                    rougher.calculation.au_pb_ratio  float64     1      1
# 29  rougher.calculation.floatbank10_sulfate_to_au_...  float64     1      1
# 69  rougher.calculation.floatbank11_sulfate_to_au_...  float64     1      1
# 78      rougher.calculation.sulfate_to_au_concentrate  float64     1      1
# 82                      rougher.output.concentrate_ag  float64     1      1
# 77                      rougher.output.concentrate_au  float64     1      1
# 55                      rougher.output.concentrate_pb  float64     1      1
# 71                     rougher.output.concentrate_sol  float64     1      1
# 65                            rougher.output.recovery  float64     1      1
# 22                             rougher.output.tail_ag  float64     1      1
# 8                              rougher.output.tail_au  float64     1      1
# 56                             rougher.output.tail_pb  float64     1      1
# 16                            rougher.output.tail_sol  float64     1      1
# 5                    secondary_cleaner.output.tail_ag  float64     1      1
# 14                   secondary_cleaner.output.tail_au  float64     1      1
# 41                   secondary_cleaner.output.tail_pb  float64     1      1
# 81                  secondary_cleaner.output.tail_sol  float64     1      1
#
#     test
# 70     0
# 42     0
# 86     0
# 83     0
# 75     0
# 36     0
# 35     0
# 54     0
# 21     0
# 19     0
# 11     0
# 49     0
# 53     0
# 76     0
# 25     0
# 60     0
# 13     0
# 47     0
# 29     0
# 69     0
# 78     0
# 82     0
# 77     0
# 55     0
# 71     0
# 65     0
# 22     0
# 8      0
# 56     0
# 16     0
# 5      0
# 14     0
# 41     0
# 81     0

# %%
describe_full(df_train)
# Out:
#                                                       count          mean  \
# final.output.concentrate_ag                         16788.0      4.716907
# final.output.concentrate_pb                         16788.0      9.113559
# final.output.concentrate_sol                        16490.0      8.301123
# final.output.concentrate_au                         16789.0     39.467217
# final.output.recovery                               15339.0     67.213166
# final.output.tail_ag                                16794.0      8.757048
# final.output.tail_pb                                16677.0      2.360327
# final.output.tail_sol                               16715.0      9.303932
# final.output.tail_au                                16794.0      2.687512
# primary_cleaner.input.sulfate                       15553.0    129.479789
# primary_cleaner.input.depressant                    15598.0      8.625021
# primary_cleaner.input.feed_size                     16860.0      7.297285
# primary_cleaner.input.xanthate                      15875.0      0.843812
# primary_cleaner.output.concentrate_ag               16778.0      7.422640
# primary_cleaner.output.concentrate_pb               16502.0      8.620294
# primary_cleaner.output.concentrate_sol              16224.0      9.171453
# primary_cleaner.output.concentrate_au               16778.0     29.164596
# primary_cleaner.output.tail_ag                      16777.0     14.916716
# primary_cleaner.output.tail_pb                      16761.0      3.165957
# primary_cleaner.output.tail_sol                     16579.0      6.746209
# primary_cleaner.output.tail_au                      16777.0      3.590534
# primary_cleaner.state.floatbank8_a_air              16820.0   1521.291691
# primary_cleaner.state.floatbank8_a_level            16827.0   -505.811103
# primary_cleaner.state.floatbank8_b_air              16820.0   1523.880015
# primary_cleaner.state.floatbank8_b_level            16833.0   -507.346105
# primary_cleaner.state.floatbank8_c_air              16822.0   1514.351131
# primary_cleaner.state.floatbank8_c_level            16833.0   -507.094373
# primary_cleaner.state.floatbank8_d_air              16821.0   1468.599116
# primary_cleaner.state.floatbank8_d_level            16833.0   -501.835392
# rougher.calculation.sulfate_to_au_concentrate       16833.0 -11372.017115
# rougher.calculation.floatbank10_sulfate_to_au_feed  16833.0   3784.836088
# rougher.calculation.floatbank11_sulfate_to_au_feed  16833.0   2017.512476
# rougher.calculation.au_pb_ratio                     15618.0      2.327953
# rougher.input.feed_ag                               16778.0      7.832347
# rougher.input.feed_pb                               16632.0      3.218931
# rougher.input.feed_rate                             16347.0    435.963431
# rougher.input.feed_size                             16443.0     58.676444
# rougher.input.feed_sol                              16568.0     32.636662
# rougher.input.feed_au                               16777.0      7.170717
# rougher.input.floatbank10_sulfate                   15816.0     11.198142
# rougher.input.floatbank10_xanthate                  16514.0      5.366609
# rougher.input.floatbank11_sulfate                   16237.0     10.550080
# rougher.input.floatbank11_xanthate                  14956.0      5.792970
# rougher.output.concentrate_ag                       16778.0     10.580475
# rougher.output.concentrate_pb                       16778.0      6.880322
# rougher.output.concentrate_sol                      16698.0     25.388996
# rougher.output.concentrate_au                       16778.0     17.401541
# rougher.output.recovery                             14287.0     82.394201
# rougher.output.tail_ag                              14610.0      5.566579
# rougher.output.tail_pb                              16778.0      0.596493
# rougher.output.tail_sol                             14611.0     17.865309
# rougher.output.tail_au                              14611.0      1.763930
# rougher.state.floatbank10_a_air                     16807.0   1077.201302
# rougher.state.floatbank10_a_level                   16807.0   -384.109359
# rougher.state.floatbank10_b_air                     16807.0   1252.285954
# rougher.state.floatbank10_b_level                   16807.0   -475.443395
# rougher.state.floatbank10_c_air                     16807.0   1229.567445
# rougher.state.floatbank10_c_level                   16814.0   -474.713811
# rougher.state.floatbank10_d_air                     16802.0   1146.785992
# rougher.state.floatbank10_d_level                   16809.0   -476.180417
# rougher.state.floatbank10_e_air                     16257.0   1033.886871
# rougher.state.floatbank10_e_level                   16809.0   -475.545309
# rougher.state.floatbank10_f_air                     16802.0    983.384202
# rougher.state.floatbank10_f_level                   16802.0   -475.980531
# secondary_cleaner.output.tail_ag                    16776.0     13.014971
# secondary_cleaner.output.tail_pb                    16764.0      5.320902
# secondary_cleaner.output.tail_sol                   14874.0      6.181742
# secondary_cleaner.output.tail_au                    16778.0      3.935796
# secondary_cleaner.state.floatbank2_a_air            16497.0     28.134535
# secondary_cleaner.state.floatbank2_a_level          16751.0   -517.777116
# secondary_cleaner.state.floatbank2_b_air            16705.0     23.619503
# secondary_cleaner.state.floatbank2_b_level          16748.0   -519.562134
# secondary_cleaner.state.floatbank3_a_air            16763.0     27.913358
# secondary_cleaner.state.floatbank3_a_level          16747.0   -493.470026
# secondary_cleaner.state.floatbank3_b_air            16752.0     21.663507
# secondary_cleaner.state.floatbank3_b_level          16750.0   -501.521561
# secondary_cleaner.state.floatbank4_a_air            16731.0     19.101874
# secondary_cleaner.state.floatbank4_a_level          16747.0   -494.164481
# secondary_cleaner.state.floatbank4_b_air            16768.0     14.778164
# secondary_cleaner.state.floatbank4_b_level          16767.0   -476.600082
# secondary_cleaner.state.floatbank5_a_air            16775.0     15.779488
# secondary_cleaner.state.floatbank5_a_level          16775.0   -500.230146
# secondary_cleaner.state.floatbank5_b_air            16775.0     12.377241
# secondary_cleaner.state.floatbank5_b_level          16776.0   -498.956257
# secondary_cleaner.state.floatbank6_a_air            16757.0     18.429208
# secondary_cleaner.state.floatbank6_a_level          16775.0   -521.801826
#
#                                                              std  \
# final.output.concentrate_ag                         2.096718e+00
# final.output.concentrate_pb                         3.389495e+00
# final.output.concentrate_sol                        3.825760e+00
# final.output.concentrate_au                         1.391723e+01
# final.output.recovery                               1.196045e+01
# final.output.tail_ag                                3.634103e+00
# final.output.tail_pb                                1.215576e+00
# final.output.tail_sol                               4.263208e+00
# final.output.tail_au                                1.272757e+00
# primary_cleaner.input.sulfate                       4.538693e+01
# primary_cleaner.input.depressant                    3.698633e+00
# primary_cleaner.input.feed_size                     6.191658e-01
# primary_cleaner.input.xanthate                      4.190981e-01
# primary_cleaner.output.concentrate_ag               3.105117e+00
# primary_cleaner.output.concentrate_pb               3.815415e+00
# primary_cleaner.output.concentrate_sol              4.901822e+00
# primary_cleaner.output.concentrate_au               1.098372e+01
# primary_cleaner.output.tail_ag                      5.940559e+00
# primary_cleaner.output.tail_pb                      1.747066e+00
# primary_cleaner.output.tail_sol                     2.999423e+00
# primary_cleaner.output.tail_au                      2.028115e+00
# primary_cleaner.state.floatbank8_a_air              3.800645e+02
# primary_cleaner.state.floatbank8_a_level            7.764029e+01
# primary_cleaner.state.floatbank8_b_air              3.812453e+02
# primary_cleaner.state.floatbank8_b_level            7.983074e+01
# primary_cleaner.state.floatbank8_c_air              3.964931e+02
# primary_cleaner.state.floatbank8_c_level            7.882316e+01
# primary_cleaner.state.floatbank8_d_air              4.443294e+02
# primary_cleaner.state.floatbank8_d_level            8.725701e+01
# rougher.calculation.sulfate_to_au_concentrate       5.754320e+06
# rougher.calculation.floatbank10_sulfate_to_au_feed  7.088720e+04
# rougher.calculation.floatbank11_sulfate_to_au_feed  4.836941e+04
# rougher.calculation.au_pb_ratio                     8.991251e-01
# rougher.input.feed_ag                               3.139014e+00
# rougher.input.feed_pb                               1.477263e+00
# rougher.input.feed_rate                             1.565922e+02
# rougher.input.feed_size                             2.392259e+01
# rougher.input.feed_sol                              1.166198e+01
# rougher.input.feed_au                               3.002113e+00
# rougher.input.floatbank10_sulfate                   3.964080e+00
# rougher.input.floatbank10_xanthate                  1.940766e+00
# rougher.input.floatbank11_sulfate                   4.560428e+00
# rougher.input.floatbank11_xanthate                  1.294180e+00
# rougher.output.concentrate_ag                       4.451490e+00
# rougher.output.concentrate_pb                       2.928757e+00
# rougher.output.concentrate_sol                      1.040053e+01
# rougher.output.concentrate_au                       6.921875e+00
# rougher.output.recovery                             1.509681e+01
# rougher.output.tail_ag                              1.045456e+00
# rougher.output.tail_pb                              3.308194e-01
# rougher.output.tail_sol                             3.455588e+00
# rougher.output.tail_au                              7.315177e-01
# rougher.state.floatbank10_a_air                     2.918009e+02
# rougher.state.floatbank10_a_level                   1.124087e+02
# rougher.state.floatbank10_b_air                     3.310767e+02
# rougher.state.floatbank10_b_level                   7.005146e+01
# rougher.state.floatbank10_c_air                     3.448403e+02
# rougher.state.floatbank10_c_level                   6.706512e+01
# rougher.state.floatbank10_d_air                     3.273118e+02
# rougher.state.floatbank10_d_level                   6.411838e+01
# rougher.state.floatbank10_e_air                     2.934562e+02
# rougher.state.floatbank10_e_level                   6.878192e+01
# rougher.state.floatbank10_f_air                     2.754263e+02
# rougher.state.floatbank10_f_level                   7.013280e+01
# secondary_cleaner.output.tail_ag                    5.960323e+00
# secondary_cleaner.output.tail_pb                    3.191103e+00
# secondary_cleaner.output.tail_sol                   4.460622e+00
# secondary_cleaner.output.tail_au                    2.675785e+00
# secondary_cleaner.state.floatbank2_a_air            8.320744e+00
# secondary_cleaner.state.floatbank2_a_level          8.955188e+01
# secondary_cleaner.state.floatbank2_b_air            8.144236e+00
# secondary_cleaner.state.floatbank2_b_level          8.937485e+01
# secondary_cleaner.state.floatbank3_a_air            8.170477e+00
# secondary_cleaner.state.floatbank3_a_level          8.529643e+01
# secondary_cleaner.state.floatbank3_b_air            6.738952e+00
# secondary_cleaner.state.floatbank3_b_level          7.472325e+01
# secondary_cleaner.state.floatbank4_a_air            6.883163e+00
# secondary_cleaner.state.floatbank4_a_level          8.480333e+01
# secondary_cleaner.state.floatbank4_b_air            5.999149e+00
# secondary_cleaner.state.floatbank4_b_level          8.938117e+01
# secondary_cleaner.state.floatbank5_a_air            6.834703e+00
# secondary_cleaner.state.floatbank5_a_level          7.698354e+01
# secondary_cleaner.state.floatbank5_b_air            6.219989e+00
# secondary_cleaner.state.floatbank5_b_level          8.214621e+01
# secondary_cleaner.state.floatbank6_a_air            6.958294e+00
# secondary_cleaner.state.floatbank6_a_level          7.717089e+01
#
#                                                              min  \
# final.output.concentrate_ag                         0.000000e+00
# final.output.concentrate_pb                         0.000000e+00
# final.output.concentrate_sol                        0.000000e+00
# final.output.concentrate_au                         0.000000e+00
# final.output.recovery                               0.000000e+00
# final.output.tail_ag                                0.000000e+00
# final.output.tail_pb                                0.000000e+00
# final.output.tail_sol                               0.000000e+00
# final.output.tail_au                                0.000000e+00
# primary_cleaner.input.sulfate                       2.567664e-06
# primary_cleaner.input.depressant                    0.000000e+00
# primary_cleaner.input.feed_size                     1.080000e+00
# primary_cleaner.input.xanthate                      4.632753e-06
# primary_cleaner.output.concentrate_ag               0.000000e+00
# primary_cleaner.output.concentrate_pb               0.000000e+00
# primary_cleaner.output.concentrate_sol              0.000000e+00
# primary_cleaner.output.concentrate_au               0.000000e+00
# primary_cleaner.output.tail_ag                      0.000000e+00
# primary_cleaner.output.tail_pb                      0.000000e+00
# primary_cleaner.output.tail_sol                     0.000000e+00
# primary_cleaner.output.tail_au                      0.000000e+00
# primary_cleaner.state.floatbank8_a_air              0.000000e+00
# primary_cleaner.state.floatbank8_a_level           -8.000374e+02
# primary_cleaner.state.floatbank8_b_air              0.000000e+00
# primary_cleaner.state.floatbank8_b_level           -8.004098e+02
# primary_cleaner.state.floatbank8_c_air              0.000000e+00
# primary_cleaner.state.floatbank8_c_level           -8.003629e+02
# primary_cleaner.state.floatbank8_d_air              0.000000e+00
# primary_cleaner.state.floatbank8_d_level           -8.001662e+02
# rougher.calculation.sulfate_to_au_concentrate      -6.643891e+08
# rougher.calculation.floatbank10_sulfate_to_au_feed -2.023459e+06
# rougher.calculation.floatbank11_sulfate_to_au_feed -4.014502e+06
# rougher.calculation.au_pb_ratio                    -1.054761e-02
# rougher.input.feed_ag                               0.000000e+00
# rougher.input.feed_pb                               0.000000e+00
# rougher.input.feed_rate                             4.442143e-05
# rougher.input.feed_size                             9.659576e+00
# rougher.input.feed_sol                              0.000000e+00
# rougher.input.feed_au                               0.000000e+00
# rougher.input.floatbank10_sulfate                   1.833866e-06
# rougher.input.floatbank10_xanthate                  2.844125e-06
# rougher.input.floatbank11_sulfate                   4.945691e-05
# rougher.input.floatbank11_xanthate                  9.685954e-06
# rougher.output.concentrate_ag                       0.000000e+00
# rougher.output.concentrate_pb                       0.000000e+00
# rougher.output.concentrate_sol                      0.000000e+00
# rougher.output.concentrate_au                       0.000000e+00
# rougher.output.recovery                             0.000000e+00
# rougher.output.tail_ag                              5.945623e-01
# rougher.output.tail_pb                              0.000000e+00
# rougher.output.tail_sol                             1.001465e+01
# rougher.output.tail_au                              2.067578e-02
# rougher.state.floatbank10_a_air                    -3.451676e-01
# rougher.state.floatbank10_a_level                  -6.582231e+02
# rougher.state.floatbank10_b_air                    -7.595680e-01
# rougher.state.floatbank10_b_level                  -6.504376e+02
# rougher.state.floatbank10_c_air                    -3.785206e-01
# rougher.state.floatbank10_c_level                  -6.501512e+02
# rougher.state.floatbank10_d_air                    -1.197435e+00
# rougher.state.floatbank10_d_level                  -6.493007e+02
# rougher.state.floatbank10_e_air                    -2.163619e+00
# rougher.state.floatbank10_e_level                  -6.501962e+02
# rougher.state.floatbank10_f_air                    -2.636171e+00
# rougher.state.floatbank10_f_level                  -6.500729e+02
# secondary_cleaner.output.tail_ag                    0.000000e+00
# secondary_cleaner.output.tail_pb                    0.000000e+00
# secondary_cleaner.output.tail_sol                   0.000000e+00
# secondary_cleaner.output.tail_au                    0.000000e+00
# secondary_cleaner.state.floatbank2_a_air            0.000000e+00
# secondary_cleaner.state.floatbank2_a_level         -7.998417e+02
# secondary_cleaner.state.floatbank2_b_air            0.000000e+00
# secondary_cleaner.state.floatbank2_b_level         -7.999680e+02
# secondary_cleaner.state.floatbank3_a_air            0.000000e+00
# secondary_cleaner.state.floatbank3_a_level         -7.999263e+02
# secondary_cleaner.state.floatbank3_b_air            0.000000e+00
# secondary_cleaner.state.floatbank3_b_level         -8.094219e+02
# secondary_cleaner.state.floatbank4_a_air            0.000000e+00
# secondary_cleaner.state.floatbank4_a_level         -7.999207e+02
# secondary_cleaner.state.floatbank4_b_air            0.000000e+00
# secondary_cleaner.state.floatbank4_b_level         -8.000218e+02
# secondary_cleaner.state.floatbank5_a_air           -4.232602e-01
# secondary_cleaner.state.floatbank5_a_level         -7.997411e+02
# secondary_cleaner.state.floatbank5_b_air            4.270836e-01
# secondary_cleaner.state.floatbank5_b_level         -8.002582e+02
# secondary_cleaner.state.floatbank6_a_air            2.427006e-02
# secondary_cleaner.state.floatbank6_a_level         -8.104735e+02
#
#                                                              25%  \
# final.output.concentrate_ag                             3.971262
# final.output.concentrate_pb                             8.825748
# final.output.concentrate_sol                            6.939185
# final.output.concentrate_au                            42.055722
# final.output.recovery                                  62.625685
# final.output.tail_ag                                    7.610544
# final.output.tail_pb                                    1.641604
# final.output.tail_sol                                   7.870275
# final.output.tail_au                                    2.172953
# primary_cleaner.input.sulfate                         103.064021
# primary_cleaner.input.depressant                        6.004886
# primary_cleaner.input.feed_size                         6.940000
# primary_cleaner.input.xanthate                          0.568934
# primary_cleaner.output.concentrate_ag                   6.612584
# primary_cleaner.output.concentrate_pb                   7.146794
# primary_cleaner.output.concentrate_sol                  6.477601
# primary_cleaner.output.concentrate_au                  29.631129
# primary_cleaner.output.tail_ag                         13.283872
# primary_cleaner.output.tail_pb                          2.162262
# primary_cleaner.output.tail_sol                         5.530088
# primary_cleaner.output.tail_au                          2.664223
# primary_cleaner.state.floatbank8_a_air               1503.883158
# primary_cleaner.state.floatbank8_a_level             -500.414946
# primary_cleaner.state.floatbank8_b_air               1502.956269
# primary_cleaner.state.floatbank8_b_level             -500.491143
# primary_cleaner.state.floatbank8_c_air               1500.685486
# primary_cleaner.state.floatbank8_c_level             -500.859360
# primary_cleaner.state.floatbank8_d_air               1418.756530
# primary_cleaner.state.floatbank8_d_level             -500.643616
# rougher.calculation.sulfate_to_au_concentrate       38988.649449
# rougher.calculation.floatbank10_sulfate_to_au_feed   2502.307799
# rougher.calculation.floatbank11_sulfate_to_au_feed   2498.157556
# rougher.calculation.au_pb_ratio                         1.979046
# rougher.input.feed_ag                                   6.889426
# rougher.input.feed_pb                                   2.551143
# rougher.input.feed_rate                               396.667936
# rougher.input.feed_size                                47.575879
# rougher.input.feed_sol                                 32.170423
# rougher.input.feed_au                                   6.203083
# rougher.input.floatbank10_sulfate                       9.366078
# rougher.input.floatbank10_xanthate                      4.802531
# rougher.input.floatbank11_sulfate                       8.903492
# rougher.input.floatbank11_xanthate                      5.097006
# rougher.output.concentrate_ag                           9.970467
# rougher.output.concentrate_pb                           6.346373
# rougher.output.concentrate_sol                         24.792988
# rougher.output.concentrate_au                          17.443663
# rougher.output.recovery                                79.818372
# rougher.output.tail_ag                                  4.918713
# rougher.output.tail_pb                                  0.413711
# rougher.output.tail_sol                                15.646980
# rougher.output.tail_au                                  1.311610
# rougher.state.floatbank10_a_air                       999.636979
# rougher.state.floatbank10_a_level                    -499.908427
# rougher.state.floatbank10_b_air                      1196.415722
# rougher.state.floatbank10_b_level                    -500.284895
# rougher.state.floatbank10_c_air                      1100.084257
# rougher.state.floatbank10_c_level                    -500.329171
# rougher.state.floatbank10_d_air                      1044.848978
# rougher.state.floatbank10_d_level                    -500.594910
# rougher.state.floatbank10_e_air                       949.615568
# rougher.state.floatbank10_e_level                    -500.395113
# rougher.state.floatbank10_f_air                       900.029475
# rougher.state.floatbank10_f_level                    -500.738649
# secondary_cleaner.output.tail_ag                       11.367185
# secondary_cleaner.output.tail_pb                        3.466609
# secondary_cleaner.output.tail_sol                       2.045824
# secondary_cleaner.output.tail_au                        2.820390
# secondary_cleaner.state.floatbank2_a_air               25.045244
# secondary_cleaner.state.floatbank2_a_level           -500.333800
# secondary_cleaner.state.floatbank2_b_air               20.110141
# secondary_cleaner.state.floatbank2_b_level           -500.348178
# secondary_cleaner.state.floatbank3_a_air               24.972364
# secondary_cleaner.state.floatbank3_a_level           -500.236661
# secondary_cleaner.state.floatbank3_b_air               19.007706
# secondary_cleaner.state.floatbank3_b_level           -500.141064
# secondary_cleaner.state.floatbank4_a_air               14.508299
# secondary_cleaner.state.floatbank4_a_level           -500.837689
# secondary_cleaner.state.floatbank4_b_air               10.741388
# secondary_cleaner.state.floatbank4_b_level           -500.269182
# secondary_cleaner.state.floatbank5_a_air               10.977713
# secondary_cleaner.state.floatbank5_a_level           -500.530594
# secondary_cleaner.state.floatbank5_b_air                8.925586
# secondary_cleaner.state.floatbank5_b_level           -500.147603
# secondary_cleaner.state.floatbank6_a_air               13.977626
# secondary_cleaner.state.floatbank6_a_level           -501.080595
#
#                                                              50%  \
# final.output.concentrate_ag                             4.869346
# final.output.concentrate_pb                            10.065316
# final.output.concentrate_sol                            8.557228
# final.output.concentrate_au                            44.498874
# final.output.recovery                                  67.644601
# final.output.tail_ag                                    9.220393
# final.output.tail_pb                                    2.453690
# final.output.tail_sol                                  10.021968
# final.output.tail_au                                    2.781132
# primary_cleaner.input.sulfate                         131.783108
# primary_cleaner.input.depressant                        8.016531
# primary_cleaner.input.feed_size                         7.285000
# primary_cleaner.input.xanthate                          0.844271
# primary_cleaner.output.concentrate_ag                   7.997143
# primary_cleaner.output.concentrate_pb                   9.618910
# primary_cleaner.output.concentrate_sol                  9.295954
# primary_cleaner.output.concentrate_au                  32.648867
# primary_cleaner.output.tail_ag                         15.554321
# primary_cleaner.output.tail_pb                          3.082745
# primary_cleaner.output.tail_sol                         7.380058
# primary_cleaner.output.tail_au                          3.404941
# primary_cleaner.state.floatbank8_a_air               1601.139322
# primary_cleaner.state.floatbank8_a_level             -499.951772
# primary_cleaner.state.floatbank8_b_air               1601.125754
# primary_cleaner.state.floatbank8_b_level             -499.985447
# primary_cleaner.state.floatbank8_c_air               1600.908740
# primary_cleaner.state.floatbank8_c_level             -499.950634
# primary_cleaner.state.floatbank8_d_air               1599.709469
# primary_cleaner.state.floatbank8_d_level             -499.908024
# rougher.calculation.sulfate_to_au_concentrate       43167.927463
# rougher.calculation.floatbank10_sulfate_to_au_feed   2854.640785
# rougher.calculation.floatbank11_sulfate_to_au_feed   2815.062375
# rougher.calculation.au_pb_ratio                         2.229144
# rougher.input.feed_ag                                   7.938193
# rougher.input.feed_pb                                   3.297050
# rougher.input.feed_rate                               488.629971
# rougher.input.feed_size                                54.104257
# rougher.input.feed_sol                                 36.354079
# rougher.input.feed_au                                   7.443530
# rougher.input.floatbank10_sulfate                      11.179351
# rougher.input.floatbank10_xanthate                      5.767015
# rougher.input.floatbank11_sulfate                      11.001027
# rougher.input.floatbank11_xanthate                      5.995942
# rougher.output.concentrate_ag                          11.459862
# rougher.output.concentrate_pb                           7.583773
# rougher.output.concentrate_sol                         28.797785
# rougher.output.concentrate_au                          19.644663
# rougher.output.recovery                                85.235997
# rougher.output.tail_ag                                  5.718038
# rougher.output.tail_pb                                  0.594959
# rougher.output.tail_sol                                17.996971
# rougher.output.tail_au                                  1.747907
# rougher.state.floatbank10_a_air                      1001.310190
# rougher.state.floatbank10_a_level                    -300.233403
# rougher.state.floatbank10_b_air                      1299.649429
# rougher.state.floatbank10_b_level                    -499.837368
# rougher.state.floatbank10_c_air                      1298.324087
# rougher.state.floatbank10_c_level                    -499.775884
# rougher.state.floatbank10_d_air                      1199.211289
# rougher.state.floatbank10_d_level                    -499.640478
# rougher.state.floatbank10_e_air                      1049.693712
# rougher.state.floatbank10_e_level                    -499.724295
# rougher.state.floatbank10_f_air                       999.828611
# rougher.state.floatbank10_f_level                    -499.576077
# secondary_cleaner.output.tail_ag                       14.773117
# secondary_cleaner.output.tail_pb                        5.164745
# secondary_cleaner.output.tail_sol                       6.194420
# secondary_cleaner.output.tail_au                        3.863798
# secondary_cleaner.state.floatbank2_a_air               29.988519
# secondary_cleaner.state.floatbank2_a_level           -499.986132
# secondary_cleaner.state.floatbank2_b_air               26.981647
# secondary_cleaner.state.floatbank2_b_level           -500.037663
# secondary_cleaner.state.floatbank3_a_air               27.999437
# secondary_cleaner.state.floatbank3_a_level           -499.908346
# secondary_cleaner.state.floatbank3_b_air               21.996298
# secondary_cleaner.state.floatbank3_b_level           -499.980536
# secondary_cleaner.state.floatbank4_a_air               19.986958
# secondary_cleaner.state.floatbank4_a_level           -499.778379
# secondary_cleaner.state.floatbank4_b_air               14.943933
# secondary_cleaner.state.floatbank4_b_level           -499.593286
# secondary_cleaner.state.floatbank5_a_air               15.998340
# secondary_cleaner.state.floatbank5_a_level           -499.784231
# secondary_cleaner.state.floatbank5_b_air               11.092839
# secondary_cleaner.state.floatbank5_b_level           -499.933330
# secondary_cleaner.state.floatbank6_a_air               18.034960
# secondary_cleaner.state.floatbank6_a_level           -500.109898
#
#                                                              75%  \
# final.output.concentrate_ag                             5.821176
# final.output.concentrate_pb                            11.054809
# final.output.concentrate_sol                           10.289741
# final.output.concentrate_au                            45.976222
# final.output.recovery                                  72.824595
# final.output.tail_ag                                   10.971110
# final.output.tail_pb                                    3.192404
# final.output.tail_sol                                  11.648573
# final.output.tail_au                                    3.416936
# primary_cleaner.input.sulfate                         159.539839
# primary_cleaner.input.depressant                       11.437819
# primary_cleaner.input.feed_size                         7.700000
# primary_cleaner.input.xanthate                          1.097080
# primary_cleaner.output.concentrate_ag                   9.399463
# primary_cleaner.output.concentrate_pb                  11.131134
# primary_cleaner.output.concentrate_sol                 12.747802
# primary_cleaner.output.concentrate_au                  35.011318
# primary_cleaner.output.tail_ag                         18.310868
# primary_cleaner.output.tail_pb                          4.190997
# primary_cleaner.output.tail_sol                         8.728101
# primary_cleaner.output.tail_au                          4.467152
# primary_cleaner.state.floatbank8_a_air               1699.304472
# primary_cleaner.state.floatbank8_a_level             -499.412584
# primary_cleaner.state.floatbank8_b_air               1699.997294
# primary_cleaner.state.floatbank8_b_level             -499.436173
# primary_cleaner.state.floatbank8_c_air               1700.221778
# primary_cleaner.state.floatbank8_c_level             -498.901452
# primary_cleaner.state.floatbank8_d_air               1699.222198
# primary_cleaner.state.floatbank8_d_level             -498.716100
# rougher.calculation.sulfate_to_au_concentrate       47811.057561
# rougher.calculation.floatbank10_sulfate_to_au_feed   3644.407648
# rougher.calculation.floatbank11_sulfate_to_au_feed   3511.394235
# rougher.calculation.au_pb_ratio                         2.637776
# rougher.input.feed_ag                                   9.829857
# rougher.input.feed_pb                                   4.181842
# rougher.input.feed_rate                               540.548376
# rougher.input.feed_size                                65.051064
# rougher.input.feed_sol                                 39.043343
# rougher.input.feed_au                                   8.965193
# rougher.input.floatbank10_sulfate                      13.203315
# rougher.input.floatbank10_xanthate                      6.501621
# rougher.input.floatbank11_sulfate                      13.004085
# rougher.input.floatbank11_xanthate                      6.695277
# rougher.output.concentrate_ag                          13.280031
# rougher.output.concentrate_pb                           8.503498
# rougher.output.concentrate_sol                         31.542677
# rougher.output.concentrate_au                          21.224486
# rougher.output.recovery                                90.131691
# rougher.output.tail_ag                                  6.308490
# rougher.output.tail_pb                                  0.779544
# rougher.output.tail_sol                                19.933255
# rougher.output.tail_au                                  2.190839
# rougher.state.floatbank10_a_air                      1299.577654
# rougher.state.floatbank10_a_level                    -299.976784
# rougher.state.floatbank10_b_air                      1432.326657
# rougher.state.floatbank10_b_level                    -400.865979
# rougher.state.floatbank10_c_air                      1448.560325
# rougher.state.floatbank10_c_level                    -401.277897
# rougher.state.floatbank10_d_air                      1307.829439
# rougher.state.floatbank10_d_level                    -402.354963
# rougher.state.floatbank10_e_air                      1199.711798
# rougher.state.floatbank10_e_level                    -401.349388
# rougher.state.floatbank10_f_air                      1099.734617
# rougher.state.floatbank10_f_level                    -402.026493
# secondary_cleaner.output.tail_ag                       17.134159
# secondary_cleaner.output.tail_pb                        7.562139
# secondary_cleaner.output.tail_sol                      10.252499
# secondary_cleaner.output.tail_au                        4.845187
# secondary_cleaner.state.floatbank2_a_air               34.771800
# secondary_cleaner.state.floatbank2_a_level           -499.620568
# secondary_cleaner.state.floatbank2_b_air               28.094066
# secondary_cleaner.state.floatbank2_b_level           -499.780945
# secondary_cleaner.state.floatbank3_a_air               34.967470
# secondary_cleaner.state.floatbank3_a_level           -495.885262
# secondary_cleaner.state.floatbank3_b_air               25.071338
# secondary_cleaner.state.floatbank3_b_level           -499.778014
# secondary_cleaner.state.floatbank4_a_air               24.983961
# secondary_cleaner.state.floatbank4_a_level           -494.648754
# secondary_cleaner.state.floatbank4_b_air               20.023751
# secondary_cleaner.state.floatbank4_b_level           -400.137948
# secondary_cleaner.state.floatbank5_a_air               20.000701
# secondary_cleaner.state.floatbank5_a_level           -496.531781
# secondary_cleaner.state.floatbank5_b_air               15.979467
# secondary_cleaner.state.floatbank5_b_level           -498.418000
# secondary_cleaner.state.floatbank6_a_air               24.984992
# secondary_cleaner.state.floatbank6_a_level           -499.565540
#
#                                                              max   dtypes  \
# final.output.concentrate_ag                         1.600195e+01  float64
# final.output.concentrate_pb                         1.703190e+01  float64
# final.output.concentrate_sol                        1.812485e+01  float64
# final.output.concentrate_au                         5.361137e+01  float64
# final.output.recovery                               1.000000e+02  float64
# final.output.tail_ag                                1.955215e+01  float64
# final.output.tail_pb                                6.086532e+00  float64
# final.output.tail_sol                               2.231773e+01  float64
# final.output.tail_au                                9.789625e+00  float64
# primary_cleaner.input.sulfate                       2.519999e+02  float64
# primary_cleaner.input.depressant                    4.000000e+01  float64
# primary_cleaner.input.feed_size                     1.047000e+01  float64
# primary_cleaner.input.xanthate                      6.027907e+00  float64
# primary_cleaner.output.concentrate_ag               1.608163e+01  float64
# primary_cleaner.output.concentrate_pb               1.708128e+01  float64
# primary_cleaner.output.concentrate_sol              2.228085e+01  float64
# primary_cleaner.output.concentrate_au               4.593393e+01  float64
# primary_cleaner.output.tail_ag                      2.945957e+01  float64
# primary_cleaner.output.tail_pb                      9.634565e+00  float64
# primary_cleaner.output.tail_sol                     2.062083e+01  float64
# primary_cleaner.output.tail_au                      1.852882e+01  float64
# primary_cleaner.state.floatbank8_a_air              2.079531e+03  float64
# primary_cleaner.state.floatbank8_a_level           -3.301342e+02  float64
# primary_cleaner.state.floatbank8_b_air              2.361414e+03  float64
# primary_cleaner.state.floatbank8_b_level           -3.362371e+02  float64
# primary_cleaner.state.floatbank8_c_air              2.042073e+03  float64
# primary_cleaner.state.floatbank8_c_level           -2.218577e+02  float64
# primary_cleaner.state.floatbank8_d_air              2.398904e+03  float64
# primary_cleaner.state.floatbank8_d_level           -2.065434e+01  float64
# rougher.calculation.sulfate_to_au_concentrate       8.332404e+07  float64
# rougher.calculation.floatbank10_sulfate_to_au_feed  6.211433e+06  float64
# rougher.calculation.floatbank11_sulfate_to_au_feed  1.537564e+06  float64
# rougher.calculation.au_pb_ratio                     3.937927e+01  float64
# rougher.input.feed_ag                               1.486965e+01  float64
# rougher.input.feed_pb                               7.142594e+00  float64
# rougher.input.feed_rate                             7.175088e+02  float64
# rougher.input.feed_size                             4.849675e+02  float64
# rougher.input.feed_sol                              4.836318e+01  float64
# rougher.input.feed_au                               1.409336e+01  float64
# rougher.input.floatbank10_sulfate                   3.611827e+01  float64
# rougher.input.floatbank10_xanthate                  3.149333e+01  float64
# rougher.input.floatbank11_sulfate                   3.798065e+01  float64
# rougher.input.floatbank11_xanthate                  9.698407e+00  float64
# rougher.output.concentrate_ag                       2.448027e+01  float64
# rougher.output.concentrate_pb                       1.839404e+01  float64
# rougher.output.concentrate_sol                      4.008999e+01  float64
# rougher.output.concentrate_au                       2.852281e+01  float64
# rougher.output.recovery                             1.000000e+02  float64
# rougher.output.tail_ag                              1.271918e+01  float64
# rougher.output.tail_pb                              3.778064e+00  float64
# rougher.output.tail_sol                             6.611719e+01  float64
# rougher.output.tail_au                              9.688980e+00  float64
# rougher.state.floatbank10_a_air                     1.521980e+03  float64
# rougher.state.floatbank10_a_level                  -1.938328e+01  float64
# rougher.state.floatbank10_b_air                     1.809194e+03  float64
# rougher.state.floatbank10_b_level                   9.457822e+00  float64
# rougher.state.floatbank10_c_air                     2.499129e+03  float64
# rougher.state.floatbank10_c_level                  -1.024266e+01  float64
# rougher.state.floatbank10_d_air                     2.077223e+03  float64
# rougher.state.floatbank10_d_level                   2.136503e+01  float64
# rougher.state.floatbank10_e_air                     2.330310e+03  float64
# rougher.state.floatbank10_e_level                  -2.406020e+00  float64
# rougher.state.floatbank10_f_air                     1.950494e+03  float64
# rougher.state.floatbank10_f_level                  -2.174527e+01  float64
# secondary_cleaner.output.tail_ag                    2.326474e+01  float64
# secondary_cleaner.output.tail_pb                    1.704250e+01  float64
# secondary_cleaner.output.tail_sol                   3.305859e+01  float64
# secondary_cleaner.output.tail_au                    2.681164e+01  float64
# secondary_cleaner.state.floatbank2_a_air            6.000000e+01  float64
# secondary_cleaner.state.floatbank2_a_level         -1.278756e+02  float64
# secondary_cleaner.state.floatbank2_b_air            5.109322e+01  float64
# secondary_cleaner.state.floatbank2_b_level         -2.120647e+02  float64
# secondary_cleaner.state.floatbank3_a_air            6.000000e+01  float64
# secondary_cleaner.state.floatbank3_a_level         -1.916788e+02  float64
# secondary_cleaner.state.floatbank3_b_air            3.948763e+01  float64
# secondary_cleaner.state.floatbank3_b_level         -1.397715e+02  float64
# secondary_cleaner.state.floatbank4_a_air            6.000000e+01  float64
# secondary_cleaner.state.floatbank4_a_level         -1.276923e+02  float64
# secondary_cleaner.state.floatbank4_b_air            2.800383e+01  float64
# secondary_cleaner.state.floatbank4_b_level         -7.147247e+01  float64
# secondary_cleaner.state.floatbank5_a_air            6.311630e+01  float64
# secondary_cleaner.state.floatbank5_a_level         -2.750731e+02  float64
# secondary_cleaner.state.floatbank5_b_air            3.984623e+01  float64
# secondary_cleaner.state.floatbank5_b_level         -1.201909e+02  float64
# secondary_cleaner.state.floatbank6_a_air            5.487681e+01  float64
# secondary_cleaner.state.floatbank6_a_level         -3.978493e+01  float64
#
#                                                     Missing %  Cardinality  \
# final.output.concentrate_ag                          0.427046        15080
# final.output.concentrate_pb                          0.427046        15060
# final.output.concentrate_sol                         2.194543        14778
# final.output.concentrate_au                          0.421115        15081
# final.output.recovery                                9.021352        14766
# final.output.tail_ag                                 0.391459        15119
# final.output.tail_pb                                 1.085409        15002
# final.output.tail_sol                                0.860024        15040
# final.output.tail_au                                 0.391459        15119
# primary_cleaner.input.sulfate                        7.752076        15553
# primary_cleaner.input.depressant                     7.485172        15540
# primary_cleaner.input.feed_size                      0.000000         3936
# primary_cleaner.input.xanthate                       5.842230        15875
# primary_cleaner.output.concentrate_ag                0.486358        15014
# primary_cleaner.output.concentrate_pb                2.123369        14730
# primary_cleaner.output.concentrate_sol               3.772242        14457
# primary_cleaner.output.concentrate_au                0.486358        15011
# primary_cleaner.output.tail_ag                       0.492289        15198
# primary_cleaner.output.tail_pb                       0.587189        15182
# primary_cleaner.output.tail_sol                      1.666667        15000
# primary_cleaner.output.tail_au                       0.492289        15198
# primary_cleaner.state.floatbank8_a_air               0.237248        16079
# primary_cleaner.state.floatbank8_a_level             0.195730        16826
# primary_cleaner.state.floatbank8_b_air               0.237248        16168
# primary_cleaner.state.floatbank8_b_level             0.160142        16827
# primary_cleaner.state.floatbank8_c_air               0.225386        16105
# primary_cleaner.state.floatbank8_c_level             0.160142        16828
# primary_cleaner.state.floatbank8_d_air               0.231317        16102
# primary_cleaner.state.floatbank8_d_level             0.160142        16828
# rougher.calculation.sulfate_to_au_concentrate        0.160142        16833
# rougher.calculation.floatbank10_sulfate_to_au_feed   0.160142        16833
# rougher.calculation.floatbank11_sulfate_to_au_feed   0.160142        16833
# rougher.calculation.au_pb_ratio                      7.366548        15221
# rougher.input.feed_ag                                0.486358        15224
# rougher.input.feed_pb                                1.352313        15071
# rougher.input.feed_rate                              3.042705        16347
# rougher.input.feed_size                              2.473310        16400
# rougher.input.feed_sol                               1.731910        15017
# rougher.input.feed_au                                0.492289        15223
# rougher.input.floatbank10_sulfate                    6.192171        15816
# rougher.input.floatbank10_xanthate                   2.052195        16514
# rougher.input.floatbank11_sulfate                    3.695136        16237
# rougher.input.floatbank11_xanthate                  11.293001        14941
# rougher.output.concentrate_ag                        0.486358        14815
# rougher.output.concentrate_pb                        0.486358        14787
# rougher.output.concentrate_sol                       0.960854        14536
# rougher.output.concentrate_au                        0.486358        14815
# rougher.output.recovery                             15.260973        13945
# rougher.output.tail_ag                              13.345196        14575
# rougher.output.tail_pb                               0.486358        15183
# rougher.output.tail_sol                             13.339265        14466
# rougher.output.tail_au                              13.339265        14577
# rougher.state.floatbank10_a_air                      0.314353        16803
# rougher.state.floatbank10_a_level                    0.314353        16803
# rougher.state.floatbank10_b_air                      0.314353        16803
# rougher.state.floatbank10_b_level                    0.314353        16803
# rougher.state.floatbank10_c_air                      0.314353        16798
# rougher.state.floatbank10_c_level                    0.272835        16812
# rougher.state.floatbank10_d_air                      0.344009        16799
# rougher.state.floatbank10_d_level                    0.302491        16809
# rougher.state.floatbank10_e_air                      3.576512        16252
# rougher.state.floatbank10_e_level                    0.302491        16806
# rougher.state.floatbank10_f_air                      0.344009        16797
# rougher.state.floatbank10_f_level                    0.344009        16702
# secondary_cleaner.output.tail_ag                     0.498221        14460
# secondary_cleaner.output.tail_pb                     0.569395        14446
# secondary_cleaner.output.tail_sol                   11.779359        12559
# secondary_cleaner.output.tail_au                     0.486358        14462
# secondary_cleaner.state.floatbank2_a_air             2.153025        16481
# secondary_cleaner.state.floatbank2_a_level           0.646501        16732
# secondary_cleaner.state.floatbank2_b_air             0.919336        15925
# secondary_cleaner.state.floatbank2_b_level           0.664294        16740
# secondary_cleaner.state.floatbank3_a_air             0.575326        16113
# secondary_cleaner.state.floatbank3_a_level           0.670225        16736
# secondary_cleaner.state.floatbank3_b_air             0.640569        16111
# secondary_cleaner.state.floatbank3_b_level           0.652432        16746
# secondary_cleaner.state.floatbank4_a_air             0.765125        16099
# secondary_cleaner.state.floatbank4_a_level           0.670225        16728
# secondary_cleaner.state.floatbank4_b_air             0.545670        16121
# secondary_cleaner.state.floatbank4_b_level           0.551601        16759
# secondary_cleaner.state.floatbank5_a_air             0.504152        16759
# secondary_cleaner.state.floatbank5_a_level           0.504152        16766
# secondary_cleaner.state.floatbank5_b_air             0.504152        16764
# secondary_cleaner.state.floatbank5_b_level           0.498221        16760
# secondary_cleaner.state.floatbank6_a_air             0.610913        16748
# secondary_cleaner.state.floatbank6_a_level           0.504152        16758
#
#                                                           Skew  outliers  \
# final.output.concentrate_ag                          -0.387984        85
# final.output.concentrate_pb                          -1.836723         0
# final.output.concentrate_sol                         -0.530965         0
# final.output.concentrate_au                          -2.304386         0
# final.output.recovery                                -1.121900       185
# final.output.tail_ag                                 -1.041155         0
# final.output.tail_pb                                 -0.271486         1
# final.output.tail_sol                                -0.628713         3
# final.output.tail_au                                 -0.249678        74
# primary_cleaner.input.sulfate                        -0.415546         0
# primary_cleaner.input.depressant                      0.270044        23
# primary_cleaner.input.feed_size                      -0.467672        72
# primary_cleaner.input.xanthate                        0.359868        30
# primary_cleaner.output.concentrate_ag                -1.212999         0
# primary_cleaner.output.concentrate_pb                -1.036345         0
# primary_cleaner.output.concentrate_sol               -0.239898         0
# primary_cleaner.output.concentrate_au                -1.950261         0
# primary_cleaner.output.tail_ag                       -1.127580         0
# primary_cleaner.output.tail_pb                        0.237398        91
# primary_cleaner.output.tail_sol                      -0.873418         7
# primary_cleaner.output.tail_au                        1.148468       234
# primary_cleaner.state.floatbank8_a_air               -3.339234       887
# primary_cleaner.state.floatbank8_a_level             -2.383160       951
# primary_cleaner.state.floatbank8_b_air               -3.307686       885
# primary_cleaner.state.floatbank8_b_level             -2.534403       962
# primary_cleaner.state.floatbank8_c_air               -3.155417       970
# primary_cleaner.state.floatbank8_c_level             -2.465033       872
# primary_cleaner.state.floatbank8_d_air               -1.880861       874
# primary_cleaner.state.floatbank8_d_level             -1.628371       974
# rougher.calculation.sulfate_to_au_concentrate      -101.681431         6
# rougher.calculation.floatbank10_sulfate_to_au_feed   68.459052        20
# rougher.calculation.floatbank11_sulfate_to_au_feed  -58.838032        44
# rougher.calculation.au_pb_ratio                      10.254464       115
# rougher.input.feed_ag                                -1.043353         0
# rougher.input.feed_pb                                -0.519793         0
# rougher.input.feed_rate                              -1.499461         0
# rougher.input.feed_size                               6.483424       156
# rougher.input.feed_sol                               -2.006816         0
# rougher.input.feed_au                                -0.936388         0
# rougher.input.floatbank10_sulfate                    -0.271840        66
# rougher.input.floatbank10_xanthate                   -1.021220         8
# rougher.input.floatbank11_sulfate                    -0.578282        51
# rougher.input.floatbank11_xanthate                   -1.204436       257
# rougher.output.concentrate_ag                        -1.359666         1
# rougher.output.concentrate_pb                        -1.251523         2
# rougher.output.concentrate_sol                       -1.637696         0
# rougher.output.concentrate_au                        -1.789231         0
# rougher.output.recovery                              -3.892141       358
# rougher.output.tail_ag                               -0.291888        28
# rougher.output.tail_pb                                0.763623       136
# rougher.output.tail_sol                               1.496908        48
# rougher.output.tail_au                                0.878900       102
# rougher.state.floatbank10_a_air                      -2.069697       784
# rougher.state.floatbank10_a_level                    -0.870736        10
# rougher.state.floatbank10_b_air                      -2.342816       785
# rougher.state.floatbank10_b_level                     0.397881        23
# rougher.state.floatbank10_c_air                      -1.877771       821
# rougher.state.floatbank10_c_level                     0.627802        26
# rougher.state.floatbank10_d_air                      -1.746514       774
# rougher.state.floatbank10_d_level                     0.421407         5
# rougher.state.floatbank10_e_air                      -1.728609       777
# rougher.state.floatbank10_e_level                     0.497472        33
# rougher.state.floatbank10_f_air                      -1.628104       775
# rougher.state.floatbank10_f_level                     0.280618        40
# secondary_cleaner.output.tail_ag                     -1.241432         0
# secondary_cleaner.output.tail_pb                      0.078104        38
# secondary_cleaner.output.tail_sol                     0.051980         1
# secondary_cleaner.output.tail_au                      1.948061       240
# secondary_cleaner.state.floatbank2_a_air             -1.731761       367
# secondary_cleaner.state.floatbank2_a_level           -2.210117      1156
# secondary_cleaner.state.floatbank2_b_air             -1.686566         1
# secondary_cleaner.state.floatbank2_b_level           -2.158578       718
# secondary_cleaner.state.floatbank3_a_air             -1.570515       768
# secondary_cleaner.state.floatbank3_a_level           -2.085871       869
# secondary_cleaner.state.floatbank3_b_air             -1.156482       746
# secondary_cleaner.state.floatbank3_b_level           -2.085545       922
# secondary_cleaner.state.floatbank4_a_air             -0.610852         7
# secondary_cleaner.state.floatbank4_a_level           -2.108844       861
# secondary_cleaner.state.floatbank4_b_air             -0.353909         0
# secondary_cleaner.state.floatbank4_b_level           -1.817195       799
# secondary_cleaner.state.floatbank5_a_air             -0.027743        11
# secondary_cleaner.state.floatbank5_a_level           -2.421188       877
# secondary_cleaner.state.floatbank5_b_air              0.355130         9
# secondary_cleaner.state.floatbank5_b_level           -2.013278       941
# secondary_cleaner.state.floatbank6_a_air             -0.477110         3
# secondary_cleaner.state.floatbank6_a_level           -2.393971       948
#
#                                                         kurtosis
# final.output.concentrate_ag                             1.641871
# final.output.concentrate_pb                             2.495092
# final.output.concentrate_sol                            0.472459
# final.output.concentrate_au                             3.694380
# final.output.recovery                                   7.843730
# final.output.tail_ag                                    1.138972
# final.output.tail_pb                                   -0.349192
# final.output.tail_sol                                   0.567390
# final.output.tail_au                                    1.016920
# primary_cleaner.input.sulfate                           0.360658
# primary_cleaner.input.depressant                        0.657536
# primary_cleaner.input.feed_size                         5.110211
# primary_cleaner.input.xanthate                          1.998205
# primary_cleaner.output.concentrate_ag                   1.010366
# primary_cleaner.output.concentrate_pb                   0.407764
# primary_cleaner.output.concentrate_sol                 -0.473802
# primary_cleaner.output.concentrate_au                   2.537732
# primary_cleaner.output.tail_ag                          1.469703
# primary_cleaner.output.tail_pb                          0.176600
# primary_cleaner.output.tail_sol                         0.325179
# primary_cleaner.output.tail_au                          4.890302
# primary_cleaner.state.floatbank8_a_air                 10.562859
# primary_cleaner.state.floatbank8_a_level                7.644439
# primary_cleaner.state.floatbank8_b_air                 10.425740
# primary_cleaner.state.floatbank8_b_level                7.849907
# primary_cleaner.state.floatbank8_c_air                  9.245811
# primary_cleaner.state.floatbank8_c_level                7.693504
# primary_cleaner.state.floatbank8_d_air                  4.320869
# primary_cleaner.state.floatbank8_d_level                6.279281
# rougher.calculation.sulfate_to_au_concentrate       11143.592878
# rougher.calculation.floatbank10_sulfate_to_au_feed   6009.815103
# rougher.calculation.floatbank11_sulfate_to_au_feed   4978.368194
# rougher.calculation.au_pb_ratio                       285.057290
# rougher.input.feed_ag                                   1.249009
# rougher.input.feed_pb                                   0.166710
# rougher.input.feed_rate                                 1.699524
# rougher.input.feed_size                                69.832625
# rougher.input.feed_sol                                  2.997202
# rougher.input.feed_au                                   0.809134
# rougher.input.floatbank10_sulfate                       2.450668
# rougher.input.floatbank10_xanthate                      7.583118
# rougher.input.floatbank11_sulfate                       1.199348
# rougher.input.floatbank11_xanthate                      3.652687
# rougher.output.concentrate_ag                           1.190268
# rougher.output.concentrate_pb                           1.135858
# rougher.output.concentrate_sol                          1.466305
# rougher.output.concentrate_au                           1.918750
# rougher.output.recovery                                18.107440
# rougher.output.tail_ag                                  0.355853
# rougher.output.tail_pb                                  4.434065
# rougher.output.tail_sol                                18.210655
# rougher.output.tail_au                                  5.113340
# rougher.state.floatbank10_a_air                         6.032014
# rougher.state.floatbank10_a_level                      -0.492029
# rougher.state.floatbank10_b_air                         6.856174
# rougher.state.floatbank10_b_level                       2.824688
# rougher.state.floatbank10_c_air                         5.271256
# rougher.state.floatbank10_c_level                       3.265815
# rougher.state.floatbank10_d_air                         4.499812
# rougher.state.floatbank10_d_level                       1.223407
# rougher.state.floatbank10_e_air                         5.090903
# rougher.state.floatbank10_e_level                       3.017096
# rougher.state.floatbank10_f_air                         5.526038
# rougher.state.floatbank10_f_level                       2.268511
# secondary_cleaner.output.tail_ag                        0.442508
# secondary_cleaner.output.tail_pb                       -0.294471
# secondary_cleaner.output.tail_sol                      -1.228385
# secondary_cleaner.output.tail_au                       10.764651
# secondary_cleaner.state.floatbank2_a_air                3.342515
# secondary_cleaner.state.floatbank2_a_level              5.224156
# secondary_cleaner.state.floatbank2_b_air                2.432920
# secondary_cleaner.state.floatbank2_b_level              4.649226
# secondary_cleaner.state.floatbank3_a_air                3.790584
# secondary_cleaner.state.floatbank3_a_level              6.056762
# secondary_cleaner.state.floatbank3_b_air                2.748455
# secondary_cleaner.state.floatbank3_b_level              8.270220
# secondary_cleaner.state.floatbank4_a_air                0.905266
# secondary_cleaner.state.floatbank4_a_level              6.119797
# secondary_cleaner.state.floatbank4_b_air               -0.258448
# secondary_cleaner.state.floatbank4_b_level              5.263602
# secondary_cleaner.state.floatbank5_a_air                0.675787
# secondary_cleaner.state.floatbank5_a_level              7.797770
# secondary_cleaner.state.floatbank5_b_air               -0.484077
# secondary_cleaner.state.floatbank5_b_level              8.105520
# secondary_cleaner.state.floatbank6_a_air                0.347773
# secondary_cleaner.state.floatbank6_a_level              7.991425

# %%
describe_full(df_test)
# Out:
#                                              count         mean         std  \
# primary_cleaner.input.sulfate               5554.0   170.515243   49.608602
# primary_cleaner.input.depressant            5572.0     8.482873    3.353105
# primary_cleaner.input.feed_size             5856.0     7.264651    0.611526
# primary_cleaner.input.xanthate              5690.0     1.321420    0.693246
# primary_cleaner.state.floatbank8_a_air      5840.0  1481.990241  310.453166
# primary_cleaner.state.floatbank8_a_level    5840.0  -509.057796   61.339256
# primary_cleaner.state.floatbank8_b_air      5840.0  1486.908670  313.224286
# primary_cleaner.state.floatbank8_b_level    5840.0  -511.743956   67.139074
# primary_cleaner.state.floatbank8_c_air      5840.0  1468.495216  309.980748
# primary_cleaner.state.floatbank8_c_level    5840.0  -509.741212   62.671873
# primary_cleaner.state.floatbank8_d_air      5840.0  1486.398557  313.725248
# primary_cleaner.state.floatbank8_d_level    5840.0  -510.723606   65.417633
# rougher.input.feed_ag                       5840.0     8.736170    2.985805
# rougher.input.feed_pb                       5840.0     3.552722    1.326113
# rougher.input.feed_rate                     5816.0   458.485472  155.958272
# rougher.input.feed_size                     5834.0    55.937535   22.724254
# rougher.input.feed_sol                      5789.0    35.105834   10.793249
# rougher.input.feed_au                       5840.0     8.700930    2.803046
# rougher.input.floatbank10_sulfate           5599.0    13.439933    3.997715
# rougher.input.floatbank10_xanthate          5733.0     6.169553    1.673606
# rougher.input.floatbank11_sulfate           5801.0    13.056047    4.533948
# rougher.input.floatbank11_xanthate          5503.0     6.423566    1.120371
# rougher.state.floatbank10_a_air             5839.0  1016.294703  226.494775
# rougher.state.floatbank10_a_level           5840.0  -404.977728  100.953782
# rougher.state.floatbank10_b_air             5839.0  1270.598553  285.247715
# rougher.state.floatbank10_b_level           5840.0  -482.154567   55.399631
# rougher.state.floatbank10_c_air             5839.0  1253.495045  290.703157
# rougher.state.floatbank10_c_level           5840.0  -480.945868   53.759053
# rougher.state.floatbank10_d_air             5839.0  1169.675564  285.407244
# rougher.state.floatbank10_d_level           5840.0  -482.152253   54.967985
# rougher.state.floatbank10_e_air             5839.0  1018.386311  231.675756
# rougher.state.floatbank10_e_level           5840.0  -476.551547   67.002595
# rougher.state.floatbank10_f_air             5839.0   962.005375  220.862435
# rougher.state.floatbank10_f_level           5840.0  -477.795380   68.342305
# secondary_cleaner.state.floatbank2_a_air    5836.0    25.479808    5.450424
# secondary_cleaner.state.floatbank2_a_level  5840.0  -513.714941   62.448366
# secondary_cleaner.state.floatbank2_b_air    5833.0    21.083475    5.940017
# secondary_cleaner.state.floatbank2_b_level  5840.0  -512.325717   63.376776
# secondary_cleaner.state.floatbank3_a_air    5822.0    24.345831    7.950733
# secondary_cleaner.state.floatbank3_a_level  5840.0  -519.417733   73.968109
# secondary_cleaner.state.floatbank3_b_air    5840.0    20.068079    7.644391
# secondary_cleaner.state.floatbank3_b_level  5840.0  -515.028316   60.457838
# secondary_cleaner.state.floatbank4_a_air    5840.0    15.636031    4.660835
# secondary_cleaner.state.floatbank4_a_level  5840.0  -516.266074   62.756748
# secondary_cleaner.state.floatbank4_b_air    5840.0    13.145702    4.304086
# secondary_cleaner.state.floatbank4_b_level  5840.0  -476.338907  105.549424
# secondary_cleaner.state.floatbank5_a_air    5840.0    12.308967    3.762827
# secondary_cleaner.state.floatbank5_a_level  5840.0  -512.208126   58.864651
# secondary_cleaner.state.floatbank5_b_air    5840.0     9.470986    3.312471
# secondary_cleaner.state.floatbank5_b_level  5840.0  -505.017827   68.785898
# secondary_cleaner.state.floatbank6_a_air    5840.0    16.678722    5.404514
# secondary_cleaner.state.floatbank6_a_level  5840.0  -512.351694   69.919839
#
#                                                    min          25%  \
# primary_cleaner.input.sulfate                 0.000103   143.340022
# primary_cleaner.input.depressant              0.000031     6.411500
# primary_cleaner.input.feed_size               5.650000     6.885625
# primary_cleaner.input.xanthate                0.000003     0.888769
# primary_cleaner.state.floatbank8_a_air        0.000000  1497.190681
# primary_cleaner.state.floatbank8_a_level   -799.773788  -500.455211
# primary_cleaner.state.floatbank8_b_air        0.000000  1497.150234
# primary_cleaner.state.floatbank8_b_level   -800.029078  -500.936639
# primary_cleaner.state.floatbank8_c_air        0.000000  1437.050321
# primary_cleaner.state.floatbank8_c_level   -799.995127  -501.300441
# primary_cleaner.state.floatbank8_d_air        0.000000  1498.407528
# primary_cleaner.state.floatbank8_d_level   -799.838846  -500.553630
# rougher.input.feed_ag                         0.000000     7.598683
# rougher.input.feed_pb                         0.000000     3.079145
# rougher.input.feed_rate                       0.002986   399.781738
# rougher.input.feed_size                       0.046369    43.890852
# rougher.input.feed_sol                        0.000000    33.381580
# rougher.input.feed_au                         0.000000     7.763634
# rougher.input.floatbank10_sulfate             0.000154    11.006487
# rougher.input.floatbank10_xanthate            0.000052     5.884416
# rougher.input.floatbank11_sulfate             0.000014    10.999216
# rougher.input.floatbank11_xanthate            0.000055     5.994363
# rougher.state.floatbank10_a_air              -0.123194   998.970605
# rougher.state.floatbank10_a_level          -657.949759  -499.971279
# rougher.state.floatbank10_b_air              -0.821921  1199.500725
# rougher.state.floatbank10_b_level          -650.349159  -500.327705
# rougher.state.floatbank10_c_air              -0.282087  1195.460415
# rougher.state.floatbank10_c_level          -650.000000  -500.310780
# rougher.state.floatbank10_d_air              -1.047388  1004.580472
# rougher.state.floatbank10_d_level          -648.390665  -500.582886
# rougher.state.floatbank10_e_air              -2.076798   998.870710
# rougher.state.floatbank10_e_level          -650.152533  -500.268985
# rougher.state.floatbank10_f_air              -2.593390   900.518560
# rougher.state.floatbank10_f_level          -650.034631  -500.769058
# secondary_cleaner.state.floatbank2_a_air      0.000000    24.908789
# secondary_cleaner.state.floatbank2_a_level -799.608557  -500.244425
# secondary_cleaner.state.floatbank2_b_air      0.000000    19.964880
# secondary_cleaner.state.floatbank2_b_level -798.467243  -500.252962
# secondary_cleaner.state.floatbank3_a_air      0.000000    22.033603
# secondary_cleaner.state.floatbank3_a_level -799.755798  -500.368334
# secondary_cleaner.state.floatbank3_b_air      0.000000    15.979792
# secondary_cleaner.state.floatbank3_b_level -809.333008  -500.172778
# secondary_cleaner.state.floatbank4_a_air      0.000000    12.057838
# secondary_cleaner.state.floatbank4_a_level -799.798523  -501.054741
# secondary_cleaner.state.floatbank4_b_air      0.000000    11.880119
# secondary_cleaner.state.floatbank4_b_level -800.836914  -500.419113
# secondary_cleaner.state.floatbank5_a_air     -0.223393    10.123459
# secondary_cleaner.state.floatbank5_a_level -799.661076  -500.879383
# secondary_cleaner.state.floatbank5_b_air      0.528083     7.991208
# secondary_cleaner.state.floatbank5_b_level -800.220337  -500.223089
# secondary_cleaner.state.floatbank6_a_air     -0.079426    13.012422
# secondary_cleaner.state.floatbank6_a_level -809.859706  -500.833821
#
#                                                     50%          75%  \
# primary_cleaner.input.sulfate                176.103893   207.240761
# primary_cleaner.input.depressant               8.023252    10.017725
# primary_cleaner.input.feed_size                7.259333     7.650000
# primary_cleaner.input.xanthate                 1.183362     1.763797
# primary_cleaner.state.floatbank8_a_air      1554.659783  1601.681656
# primary_cleaner.state.floatbank8_a_level    -499.997402  -499.575313
# primary_cleaner.state.floatbank8_b_air      1553.268084  1601.784707
# primary_cleaner.state.floatbank8_b_level    -500.066588  -499.323361
# primary_cleaner.state.floatbank8_c_air      1546.160672  1600.785573
# primary_cleaner.state.floatbank8_c_level    -500.079537  -499.009545
# primary_cleaner.state.floatbank8_d_air      1552.089348  1600.781243
# primary_cleaner.state.floatbank8_d_level    -500.045560  -499.612913
# rougher.input.feed_ag                          9.628324    10.568373
# rougher.input.feed_pb                          3.679706     4.241195
# rougher.input.feed_rate                      489.533016   568.111571
# rougher.input.feed_size                       50.002004    61.638434
# rougher.input.feed_sol                        37.336634    41.388612
# rougher.input.feed_au                          9.449623    10.377337
# rougher.input.floatbank10_sulfate             14.000240    16.674640
# rougher.input.floatbank10_xanthate             6.401502     7.002358
# rougher.input.floatbank11_sulfate             13.998778    16.375267
# rougher.input.floatbank11_xanthate             6.496105     7.008034
# rougher.state.floatbank10_a_air             1000.327062  1005.088855
# rougher.state.floatbank10_a_level           -399.817250  -300.074857
# rougher.state.floatbank10_b_air             1300.983516  1403.256153
# rougher.state.floatbank10_b_level           -499.875575  -497.613901
# rougher.state.floatbank10_c_air             1298.509443  1401.907624
# rougher.state.floatbank10_c_level           -499.810503  -497.343773
# rougher.state.floatbank10_d_air             1202.899254  1357.767099
# rougher.state.floatbank10_d_level           -499.757267  -495.583327
# rougher.state.floatbank10_e_air             1001.670995  1100.884720
# rougher.state.floatbank10_e_level           -499.801509  -497.815261
# rougher.state.floatbank10_f_air              999.088194  1050.044643
# rougher.state.floatbank10_f_level           -499.754468  -495.576639
# secondary_cleaner.state.floatbank2_a_air      26.862173    28.052589
# secondary_cleaner.state.floatbank2_a_level  -500.017410  -499.798265
# secondary_cleaner.state.floatbank2_b_air      22.909020    24.951835
# secondary_cleaner.state.floatbank2_b_level  -500.031103  -499.836572
# secondary_cleaner.state.floatbank3_a_air      25.000337    29.994405
# secondary_cleaner.state.floatbank3_a_level  -500.053137  -499.794288
# secondary_cleaner.state.floatbank3_b_air      20.028317    26.958680
# secondary_cleaner.state.floatbank3_b_level  -500.023768  -499.895641
# secondary_cleaner.state.floatbank4_a_air      17.001867    18.030985
# secondary_cleaner.state.floatbank4_a_level  -500.160145  -499.441529
# secondary_cleaner.state.floatbank4_b_air      14.952102    15.940011
# secondary_cleaner.state.floatbank4_b_level  -499.644328  -401.523664
# secondary_cleaner.state.floatbank5_a_air      12.062877    15.017881
# secondary_cleaner.state.floatbank5_a_level  -500.047621  -499.297033
# secondary_cleaner.state.floatbank5_b_air       9.980774    11.992176
# secondary_cleaner.state.floatbank5_b_level  -500.001338  -499.722835
# secondary_cleaner.state.floatbank6_a_air      16.007242    21.009076
# secondary_cleaner.state.floatbank6_a_level  -500.041085  -499.395621
#
#                                                     max   dtypes  Missing %  \
# primary_cleaner.input.sulfate                274.409626  float64   5.157104
# primary_cleaner.input.depressant              40.024582  float64   4.849727
# primary_cleaner.input.feed_size               15.500000  float64   0.000000
# primary_cleaner.input.xanthate                 5.433169  float64   2.834699
# primary_cleaner.state.floatbank8_a_air      2212.432090  float64   0.273224
# primary_cleaner.state.floatbank8_a_level     -57.195404  float64   0.273224
# primary_cleaner.state.floatbank8_b_air      1975.147923  float64   0.273224
# primary_cleaner.state.floatbank8_b_level    -142.527229  float64   0.273224
# primary_cleaner.state.floatbank8_c_air      1715.053773  float64   0.273224
# primary_cleaner.state.floatbank8_c_level    -150.937035  float64   0.273224
# primary_cleaner.state.floatbank8_d_air      1913.256561  float64   0.273224
# primary_cleaner.state.floatbank8_d_level     -32.449456  float64   0.273224
# rougher.input.feed_ag                         14.406130  float64   0.273224
# rougher.input.feed_pb                          6.905684  float64   0.273224
# rougher.input.feed_rate                      707.364020  float64   0.683060
# rougher.input.feed_size                      477.445473  float64   0.375683
# rougher.input.feed_sol                        53.477742  float64   1.144126
# rougher.input.feed_au                         13.731330  float64   0.273224
# rougher.input.floatbank10_sulfate             24.280636  float64   4.388661
# rougher.input.floatbank10_xanthate            13.037750  float64   2.100410
# rougher.input.floatbank11_sulfate             28.949609  float64   0.939208
# rougher.input.floatbank11_xanthate            18.709478  float64   6.028005
# rougher.state.floatbank10_a_air             1423.274687  float64   0.290301
# rougher.state.floatbank10_a_level           -273.776101  float64   0.273224
# rougher.state.floatbank10_b_air             1706.640419  float64   0.290301
# rougher.state.floatbank10_b_level           -229.396203  float64   0.273224
# rougher.state.floatbank10_c_air             1809.889686  float64   0.290301
# rougher.state.floatbank10_c_level           -253.054587  float64   0.273224
# rougher.state.floatbank10_d_air             1775.218584  float64   0.290301
# rougher.state.floatbank10_d_level            -76.397327  float64   0.273224
# rougher.state.floatbank10_e_air             1467.184843  float64   0.290301
# rougher.state.floatbank10_e_level           -139.753025  float64   0.273224
# rougher.state.floatbank10_f_air             1476.588107  float64   0.290301
# rougher.state.floatbank10_f_level           -218.472824  float64   0.273224
# secondary_cleaner.state.floatbank2_a_air      59.944409  float64   0.341530
# secondary_cleaner.state.floatbank2_a_level  -300.343670  float64   0.273224
# secondary_cleaner.state.floatbank2_b_air      60.000000  float64   0.392760
# secondary_cleaner.state.floatbank2_b_level  -211.999273  float64   0.273224
# secondary_cleaner.state.floatbank3_a_air      40.041997  float64   0.580601
# secondary_cleaner.state.floatbank3_a_level  -313.866425  float64   0.273224
# secondary_cleaner.state.floatbank3_b_air      32.039365  float64   0.273224
# secondary_cleaner.state.floatbank3_b_level  -202.277366  float64   0.273224
# secondary_cleaner.state.floatbank4_a_air      30.051797  float64   0.273224
# secondary_cleaner.state.floatbank4_a_level  -401.565212  float64   0.273224
# secondary_cleaner.state.floatbank4_b_air      31.269706  float64   0.273224
# secondary_cleaner.state.floatbank4_b_level    -6.506986  float64   0.273224
# secondary_cleaner.state.floatbank5_a_air      25.258848  float64   0.273224
# secondary_cleaner.state.floatbank5_a_level  -244.483566  float64   0.273224
# secondary_cleaner.state.floatbank5_b_air      14.090194  float64   0.273224
# secondary_cleaner.state.floatbank5_b_level  -126.463446  float64   0.273224
# secondary_cleaner.state.floatbank6_a_air      26.705889  float64   0.273224
# secondary_cleaner.state.floatbank6_a_level   -29.093593  float64   0.273224
#
#                                             Cardinality      Skew  outliers  \
# primary_cleaner.input.sulfate                      5554 -0.943953       104
# primary_cleaner.input.depressant                   5572  0.691944        24
# primary_cleaner.input.feed_size                    1565  0.685361        42
# primary_cleaner.input.xanthate                     5690  0.889211        70
# primary_cleaner.state.floatbank8_a_air             5674 -3.946954       217
# primary_cleaner.state.floatbank8_a_level           5839 -3.734941       235
# primary_cleaner.state.floatbank8_b_air             5689 -3.886177       217
# primary_cleaner.state.floatbank8_b_level           5840 -3.366436       273
# primary_cleaner.state.floatbank8_c_air             5720 -3.844110       219
# primary_cleaner.state.floatbank8_c_level           5840 -3.711590       237
# primary_cleaner.state.floatbank8_d_air             5727 -3.850340       217
# primary_cleaner.state.floatbank8_d_level           5840 -3.243234       255
# rougher.input.feed_ag                              5465 -1.508672         0
# rougher.input.feed_pb                              5464 -0.914044         0
# rougher.input.feed_rate                            5816 -1.430576         0
# rougher.input.feed_size                            5834  7.365545        67
# rougher.input.feed_sol                             5412 -2.164073       373
# rougher.input.feed_au                              5465 -1.823332       371
# rougher.input.floatbank10_sulfate                  5599 -1.113887       187
# rougher.input.floatbank10_xanthate                 5733 -2.343413       288
# rougher.input.floatbank11_sulfate                  5801 -1.227439         1
# rougher.input.floatbank11_xanthate                 5503 -1.767808       100
# rougher.state.floatbank10_a_air                    5839 -2.860831       208
# rougher.state.floatbank10_a_level                  5840 -0.444494         0
# rougher.state.floatbank10_b_air                    5839 -2.963458       205
# rougher.state.floatbank10_b_level                  5839 -0.011476       284
# rougher.state.floatbank10_c_air                    5839 -2.667263       204
# rougher.state.floatbank10_c_level                  5837  0.292827       154
# rougher.state.floatbank10_d_air                    5839 -2.318391       202
# rougher.state.floatbank10_d_level                  5840  0.384722        79
# rougher.state.floatbank10_e_air                    5839 -2.751545       203
# rougher.state.floatbank10_e_level                  5840  0.792783         1
# rougher.state.floatbank10_f_air                    5839 -2.642912       204
# rougher.state.floatbank10_f_level                  5833  0.672259         5
# secondary_cleaner.state.floatbank2_a_air           5832 -2.528571       252
# secondary_cleaner.state.floatbank2_a_level         5840 -4.150216       273
# secondary_cleaner.state.floatbank2_b_air           5655 -1.777519       210
# secondary_cleaner.state.floatbank2_b_level         5838 -3.639342       285
# secondary_cleaner.state.floatbank3_a_air           5569 -1.583521       344
# secondary_cleaner.state.floatbank3_a_level         5840 -3.445771       372
# secondary_cleaner.state.floatbank3_b_air           5524 -0.833246         0
# secondary_cleaner.state.floatbank3_b_level         5840 -3.063920       309
# secondary_cleaner.state.floatbank4_a_air           5638 -1.629211       245
# secondary_cleaner.state.floatbank4_a_level         5835 -3.902562       273
# secondary_cleaner.state.floatbank4_b_air           5627 -1.389934       244
# secondary_cleaner.state.floatbank4_b_level         5840 -0.004446       382
# secondary_cleaner.state.floatbank5_a_air           5840 -0.904832       201
# secondary_cleaner.state.floatbank5_a_level         5838 -4.100327       221
# secondary_cleaner.state.floatbank5_b_air           5834 -0.773629         0
# secondary_cleaner.state.floatbank5_b_level         5840 -1.700141       285
# secondary_cleaner.state.floatbank6_a_air           5839 -0.853525       206
# secondary_cleaner.state.floatbank6_a_level         5840 -2.369634       303
#
#                                              kurtosis
# primary_cleaner.input.sulfate                1.263672
# primary_cleaner.input.depressant             3.552985
# primary_cleaner.input.feed_size              6.506883
# primary_cleaner.input.xanthate               1.593309
# primary_cleaner.state.floatbank8_a_air      16.080463
# primary_cleaner.state.floatbank8_a_level    16.833840
# primary_cleaner.state.floatbank8_b_air      15.689827
# primary_cleaner.state.floatbank8_b_level    12.765606
# primary_cleaner.state.floatbank8_c_air      15.411720
# primary_cleaner.state.floatbank8_c_level    15.718628
# primary_cleaner.state.floatbank8_d_air      15.432481
# primary_cleaner.state.floatbank8_d_level    14.196334
# rougher.input.feed_ag                        2.228947
# rougher.input.feed_pb                        1.376658
# rougher.input.feed_rate                      2.142357
# rougher.input.feed_size                     97.724188
# rougher.input.feed_sol                       4.672357
# rougher.input.feed_au                        3.403847
# rougher.input.floatbank10_sulfate            2.220296
# rougher.input.floatbank10_xanthate           6.548363
# rougher.input.floatbank11_sulfate            1.811802
# rougher.input.floatbank11_xanthate          12.091233
# rougher.state.floatbank10_a_air             11.663440
# rougher.state.floatbank10_a_level           -0.858954
# rougher.state.floatbank10_b_air             10.972691
# rougher.state.floatbank10_b_level            2.575584
# rougher.state.floatbank10_c_air              9.337697
# rougher.state.floatbank10_c_level            2.316766
# rougher.state.floatbank10_d_air              7.163901
# rougher.state.floatbank10_d_level            2.184430
# rougher.state.floatbank10_e_air             10.397297
# rougher.state.floatbank10_e_level            2.215973
# rougher.state.floatbank10_f_air             10.150619
# rougher.state.floatbank10_f_level            2.087809
# secondary_cleaner.state.floatbank2_a_air     9.547541
# secondary_cleaner.state.floatbank2_a_level  15.769712
# secondary_cleaner.state.floatbank2_b_air     4.042723
# secondary_cleaner.state.floatbank2_b_level  14.337084
# secondary_cleaner.state.floatbank3_a_air     2.807679
# secondary_cleaner.state.floatbank3_a_level  10.173255
# secondary_cleaner.state.floatbank3_b_air     0.669225
# secondary_cleaner.state.floatbank3_b_level  10.449267
# secondary_cleaner.state.floatbank4_a_air     2.996141
# secondary_cleaner.state.floatbank4_a_level  13.929584
# secondary_cleaner.state.floatbank4_b_air     1.767215
# secondary_cleaner.state.floatbank4_b_level   4.821534
# secondary_cleaner.state.floatbank5_a_air     1.704683
# secondary_cleaner.state.floatbank5_a_level  17.483453
# secondary_cleaner.state.floatbank5_b_air     0.249623
# secondary_cleaner.state.floatbank5_b_level  14.148429
# secondary_cleaner.state.floatbank6_a_air     0.982360
# secondary_cleaner.state.floatbank6_a_level  13.599516

# %% [markdown]
# <div class="alert alert-success">
#     Great! Now we know which features are unavailable in the test set
# </div>

# %% [markdown]
# 1.4. Perform data preprocessing.

# %%
for df in [df_full, df_train, df_test]:
  if "date" in df.columns:
    df["date"] = pd.to_datetime(df["date"])
    df.set_index("date", inplace=True)

# %%
print(df_train['final.output.recovery'].isna().sum())
print(df_train['rougher.output.recovery'].isna().sum())
# Out:
# 1521
# 2573

# %%
df_test.merge(df_full[['final.output.recovery', 'rougher.output.recovery']], how='left', left_index=True, right_index=True).head(2)
# Out:
#                      primary_cleaner.input.sulfate  \
# date
# 2016-09-01 00:59:59                     210.800909
# 2016-09-01 01:59:59                     215.392455
#
#                      primary_cleaner.input.depressant  \
# date
# 2016-09-01 00:59:59                         14.993118
# 2016-09-01 01:59:59                         14.987471
#
#                      primary_cleaner.input.feed_size  \
# date
# 2016-09-01 00:59:59                             8.08
# 2016-09-01 01:59:59                             8.08
#
#                      primary_cleaner.input.xanthate  \
# date
# 2016-09-01 00:59:59                        1.005021
# 2016-09-01 01:59:59                        0.990469
#
#                      primary_cleaner.state.floatbank8_a_air  \
# date
# 2016-09-01 00:59:59                             1398.981301
# 2016-09-01 01:59:59                             1398.777912
#
#                      primary_cleaner.state.floatbank8_a_level  \
# date
# 2016-09-01 00:59:59                               -500.225577
# 2016-09-01 01:59:59                               -500.057435
#
#                      primary_cleaner.state.floatbank8_b_air  \
# date
# 2016-09-01 00:59:59                             1399.144926
# 2016-09-01 01:59:59                             1398.055362
#
#                      primary_cleaner.state.floatbank8_b_level  \
# date
# 2016-09-01 00:59:59                               -499.919735
# 2016-09-01 01:59:59                               -499.778182
#
#                      primary_cleaner.state.floatbank8_c_air  \
# date
# 2016-09-01 00:59:59                             1400.102998
# 2016-09-01 01:59:59                             1396.151033
#
#                      primary_cleaner.state.floatbank8_c_level  \
# date
# 2016-09-01 00:59:59                               -500.704369
# 2016-09-01 01:59:59                               -499.240168
#
#                      primary_cleaner.state.floatbank8_d_air  \
# date
# 2016-09-01 00:59:59                             1399.001695
# 2016-09-01 01:59:59                             1399.508091
#
#                      primary_cleaner.state.floatbank8_d_level  \
# date
# 2016-09-01 00:59:59                               -499.485144
# 2016-09-01 01:59:59                               -500.416324
#
#                      rougher.input.feed_ag  rougher.input.feed_pb  \
# date
# 2016-09-01 00:59:59              13.128569               5.636710
# 2016-09-01 01:59:59              13.036280               5.526065
#
#                      rougher.input.feed_rate  rougher.input.feed_size  \
# date
# 2016-09-01 00:59:59               489.793655                62.710452
# 2016-09-01 01:59:59               490.104534                61.961163
#
#                      rougher.input.feed_sol  rougher.input.feed_au  \
# date
# 2016-09-01 00:59:59               42.022440              12.084103
# 2016-09-01 01:59:59               41.187903              11.918977
#
#                      rougher.input.floatbank10_sulfate  \
# date
# 2016-09-01 00:59:59                          16.922877
# 2016-09-01 01:59:59                          17.002532
#
#                      rougher.input.floatbank10_xanthate  \
# date
# 2016-09-01 00:59:59                            6.153479
# 2016-09-01 01:59:59                            5.999043
#
#                      rougher.input.floatbank11_sulfate  \
# date
# 2016-09-01 00:59:59                          16.867518
# 2016-09-01 01:59:59                          16.996063
#
#                      rougher.input.floatbank11_xanthate  \
# date
# 2016-09-01 00:59:59                            6.150709
# 2016-09-01 01:59:59                            6.002315
#
#                      rougher.state.floatbank10_a_air  \
# date
# 2016-09-01 00:59:59                      1001.849317
# 2016-09-01 01:59:59                       998.690785
#
#                      rougher.state.floatbank10_a_level  \
# date
# 2016-09-01 00:59:59                        -350.301265
# 2016-09-01 01:59:59                        -350.425704
#
#                      rougher.state.floatbank10_b_air  \
# date
# 2016-09-01 00:59:59                      1249.738612
# 2016-09-01 01:59:59                      1248.395457
#
#                      rougher.state.floatbank10_b_level  \
# date
# 2016-09-01 00:59:59                        -399.107531
# 2016-09-01 01:59:59                        -399.946025
#
#                      rougher.state.floatbank10_c_air  \
# date
# 2016-09-01 00:59:59                      1249.750520
# 2016-09-01 01:59:59                      1249.514451
#
#                      rougher.state.floatbank10_c_level  \
# date
# 2016-09-01 00:59:59                         -399.39673
# 2016-09-01 01:59:59                         -399.63081
#
#                      rougher.state.floatbank10_d_air  \
# date
# 2016-09-01 00:59:59                      1198.287855
# 2016-09-01 01:59:59                      1200.506459
#
#                      rougher.state.floatbank10_d_level  \
# date
# 2016-09-01 00:59:59                        -399.488594
# 2016-09-01 01:59:59                        -399.942434
#
#                      rougher.state.floatbank10_e_air  \
# date
# 2016-09-01 00:59:59                       999.472250
# 2016-09-01 01:59:59                      1000.002114
#
#                      rougher.state.floatbank10_e_level  \
# date
# 2016-09-01 00:59:59                        -399.530962
# 2016-09-01 01:59:59                        -399.491528
#
#                      rougher.state.floatbank10_f_air  \
# date
# 2016-09-01 00:59:59                       949.566189
# 2016-09-01 01:59:59                       950.200009
#
#                      rougher.state.floatbank10_f_level  \
# date
# 2016-09-01 00:59:59                        -398.180807
# 2016-09-01 01:59:59                        -405.787514
#
#                      secondary_cleaner.state.floatbank2_a_air  \
# date
# 2016-09-01 00:59:59                                 24.938200
# 2016-09-01 01:59:59                                 24.923466
#
#                      secondary_cleaner.state.floatbank2_a_level  \
# date
# 2016-09-01 00:59:59                                 -500.490963
# 2016-09-01 01:59:59                                 -499.813963
#
#                      secondary_cleaner.state.floatbank2_b_air  \
# date
# 2016-09-01 00:59:59                                 14.947607
# 2016-09-01 01:59:59                                 14.930873
#
#                      secondary_cleaner.state.floatbank2_b_level  \
# date
# 2016-09-01 00:59:59                                 -500.013837
# 2016-09-01 01:59:59                                 -500.764452
#
#                      secondary_cleaner.state.floatbank3_a_air  \
# date
# 2016-09-01 00:59:59                                 20.018166
# 2016-09-01 01:59:59                                 19.988503
#
#                      secondary_cleaner.state.floatbank3_a_level  \
# date
# 2016-09-01 00:59:59                                 -450.395995
# 2016-09-01 01:59:59                                 -450.114024
#
#                      secondary_cleaner.state.floatbank3_b_air  \
# date
# 2016-09-01 00:59:59                                 13.987058
# 2016-09-01 01:59:59                                 14.092981
#
#                      secondary_cleaner.state.floatbank3_b_level  \
# date
# 2016-09-01 00:59:59                                 -449.831513
# 2016-09-01 01:59:59                                 -450.059163
#
#                      secondary_cleaner.state.floatbank4_a_air  \
# date
# 2016-09-01 00:59:59                                 12.023554
# 2016-09-01 01:59:59                                 12.058140
#
#                      secondary_cleaner.state.floatbank4_a_level  \
# date
# 2016-09-01 00:59:59                                 -497.795834
# 2016-09-01 01:59:59                                 -498.695773
#
#                      secondary_cleaner.state.floatbank4_b_air  \
# date
# 2016-09-01 00:59:59                                  8.016656
# 2016-09-01 01:59:59                                  8.130979
#
#                      secondary_cleaner.state.floatbank4_b_level  \
# date
# 2016-09-01 00:59:59                                 -501.289139
# 2016-09-01 01:59:59                                 -499.634209
#
#                      secondary_cleaner.state.floatbank5_a_air  \
# date
# 2016-09-01 00:59:59                                  7.946562
# 2016-09-01 01:59:59                                  7.958270
#
#                      secondary_cleaner.state.floatbank5_a_level  \
# date
# 2016-09-01 00:59:59                                 -432.317850
# 2016-09-01 01:59:59                                 -525.839648
#
#                      secondary_cleaner.state.floatbank5_b_air  \
# date
# 2016-09-01 00:59:59                                  4.872511
# 2016-09-01 01:59:59                                  4.878850
#
#                      secondary_cleaner.state.floatbank5_b_level  \
# date
# 2016-09-01 00:59:59                                 -500.037437
# 2016-09-01 01:59:59                                 -500.162375
#
#                      secondary_cleaner.state.floatbank6_a_air  \
# date
# 2016-09-01 00:59:59                                 26.705889
# 2016-09-01 01:59:59                                 25.019940
#
#                      secondary_cleaner.state.floatbank6_a_level  \
# date
# 2016-09-01 00:59:59                                 -499.709414
# 2016-09-01 01:59:59                                 -499.819438
#
#                      final.output.recovery  rougher.output.recovery
# date
# 2016-09-01 00:59:59              70.273583                89.993421
# 2016-09-01 01:59:59              68.910432                88.089657

# %%
df_test = df_test.merge(df_full[['final.output.recovery', 'rougher.output.recovery']], how='left', left_index=True, right_index=True)

# %% [markdown]
# Let's fill missing data using nearest values strategy - ffill, because our gathering of our data relates to datetime (it's like in a famous joke, what's the best strategy for the weather prediction of the next day? weather of the current day)

# %%
df_train = df_train[~df_train['final.output.recovery'].isna()]
df_train = df_train[~df_train['rougher.output.recovery'].isna()]
df_train = df_train.fillna(method='ffill')

# %%
df_test = df_test[~df_test['final.output.recovery'].isna()]
df_test = df_test[~df_test['rougher.output.recovery'].isna()]
df_test = df_test.fillna(method='ffill')

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 14149 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 86 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   final.output.concentrate_ag                         14149 non-null  float64
#  1   final.output.concentrate_pb                         14149 non-null  float64
#  2   final.output.concentrate_sol                        14149 non-null  float64
#  3   final.output.concentrate_au                         14149 non-null  float64
#  4   final.output.recovery                               14149 non-null  float64
#  5   final.output.tail_ag                                14149 non-null  float64
#  6   final.output.tail_pb                                14149 non-null  float64
#  7   final.output.tail_sol                               14149 non-null  float64
#  8   final.output.tail_au                                14149 non-null  float64
#  9   primary_cleaner.input.sulfate                       14149 non-null  float64
#  10  primary_cleaner.input.depressant                    14149 non-null  float64
#  11  primary_cleaner.input.feed_size                     14149 non-null  float64
#  12  primary_cleaner.input.xanthate                      14149 non-null  float64
#  13  primary_cleaner.output.concentrate_ag               14149 non-null  float64
#  14  primary_cleaner.output.concentrate_pb               14149 non-null  float64
#  15  primary_cleaner.output.concentrate_sol              14149 non-null  float64
#  16  primary_cleaner.output.concentrate_au               14149 non-null  float64
#  17  primary_cleaner.output.tail_ag                      14149 non-null  float64
#  18  primary_cleaner.output.tail_pb                      14149 non-null  float64
#  19  primary_cleaner.output.tail_sol                     14149 non-null  float64
#  20  primary_cleaner.output.tail_au                      14149 non-null  float64
#  21  primary_cleaner.state.floatbank8_a_air              14149 non-null  float64
#  22  primary_cleaner.state.floatbank8_a_level            14149 non-null  float64
#  23  primary_cleaner.state.floatbank8_b_air              14149 non-null  float64
#  24  primary_cleaner.state.floatbank8_b_level            14149 non-null  float64
#  25  primary_cleaner.state.floatbank8_c_air              14149 non-null  float64
#  26  primary_cleaner.state.floatbank8_c_level            14149 non-null  float64
#  27  primary_cleaner.state.floatbank8_d_air              14149 non-null  float64
#  28  primary_cleaner.state.floatbank8_d_level            14149 non-null  float64
#  29  rougher.calculation.sulfate_to_au_concentrate       14149 non-null  float64
#  30  rougher.calculation.floatbank10_sulfate_to_au_feed  14149 non-null  float64
#  31  rougher.calculation.floatbank11_sulfate_to_au_feed  14149 non-null  float64
#  32  rougher.calculation.au_pb_ratio                     14149 non-null  float64
#  33  rougher.input.feed_ag                               14149 non-null  float64
#  34  rougher.input.feed_pb                               14149 non-null  float64
#  35  rougher.input.feed_rate                             14149 non-null  float64
#  36  rougher.input.feed_size                             14149 non-null  float64
#  37  rougher.input.feed_sol                              14149 non-null  float64
#  38  rougher.input.feed_au                               14149 non-null  float64
#  39  rougher.input.floatbank10_sulfate                   14149 non-null  float64
#  40  rougher.input.floatbank10_xanthate                  14149 non-null  float64
#  41  rougher.input.floatbank11_sulfate                   14149 non-null  float64
#  42  rougher.input.floatbank11_xanthate                  14149 non-null  float64
#  43  rougher.output.concentrate_ag                       14149 non-null  float64
#  44  rougher.output.concentrate_pb                       14149 non-null  float64
#  45  rougher.output.concentrate_sol                      14149 non-null  float64
#  46  rougher.output.concentrate_au                       14149 non-null  float64
#  47  rougher.output.recovery                             14149 non-null  float64
#  48  rougher.output.tail_ag                              14149 non-null  float64
#  49  rougher.output.tail_pb                              14149 non-null  float64
#  50  rougher.output.tail_sol                             14149 non-null  float64
#  51  rougher.output.tail_au                              14149 non-null  float64
#  52  rougher.state.floatbank10_a_air                     14149 non-null  float64
#  53  rougher.state.floatbank10_a_level                   14149 non-null  float64
#  54  rougher.state.floatbank10_b_air                     14149 non-null  float64
#  55  rougher.state.floatbank10_b_level                   14149 non-null  float64
#  56  rougher.state.floatbank10_c_air                     14149 non-null  float64
#  57  rougher.state.floatbank10_c_level                   14149 non-null  float64
#  58  rougher.state.floatbank10_d_air                     14149 non-null  float64
#  59  rougher.state.floatbank10_d_level                   14149 non-null  float64
#  60  rougher.state.floatbank10_e_air                     14149 non-null  float64
#  61  rougher.state.floatbank10_e_level                   14149 non-null  float64
#  62  rougher.state.floatbank10_f_air                     14149 non-null  float64
#  63  rougher.state.floatbank10_f_level                   14149 non-null  float64
#  64  secondary_cleaner.output.tail_ag                    14149 non-null  float64
#  65  secondary_cleaner.output.tail_pb                    14149 non-null  float64
#  66  secondary_cleaner.output.tail_sol                   14149 non-null  float64
#  67  secondary_cleaner.output.tail_au                    14149 non-null  float64
#  68  secondary_cleaner.state.floatbank2_a_air            14149 non-null  float64
#  69  secondary_cleaner.state.floatbank2_a_level          14149 non-null  float64
#  70  secondary_cleaner.state.floatbank2_b_air            14149 non-null  float64
#  71  secondary_cleaner.state.floatbank2_b_level          14149 non-null  float64
#  72  secondary_cleaner.state.floatbank3_a_air            14149 non-null  float64
#  73  secondary_cleaner.state.floatbank3_a_level          14149 non-null  float64
#  74  secondary_cleaner.state.floatbank3_b_air            14149 non-null  float64
#  75  secondary_cleaner.state.floatbank3_b_level          14149 non-null  float64
#  76  secondary_cleaner.state.floatbank4_a_air            14149 non-null  float64
#  77  secondary_cleaner.state.floatbank4_a_level          14149 non-null  float64
#  78  secondary_cleaner.state.floatbank4_b_air            14149 non-null  float64
#  79  secondary_cleaner.state.floatbank4_b_level          14149 non-null  float64
#  80  secondary_cleaner.state.floatbank5_a_air            14149 non-null  float64
#  81  secondary_cleaner.state.floatbank5_a_level          14149 non-null  float64
#  82  secondary_cleaner.state.floatbank5_b_air            14149 non-null  float64
#  83  secondary_cleaner.state.floatbank5_b_level          14149 non-null  float64
#  84  secondary_cleaner.state.floatbank6_a_air            14149 non-null  float64
#  85  secondary_cleaner.state.floatbank6_a_level          14149 non-null  float64
# dtypes: float64(86)
# memory usage: 9.4 MB

# %% [markdown]
# <div class="alert alert-success">
#     Well done! You prepared the data and dealt with missing values
# </div>

# %% [markdown]
# 2. Analyze the data

# %% [markdown]
# 2.1. Take note of how the concentrations of metals (Au, Ag, Pb) change depending on the purification stage.

# %% [markdown]
# 2.2. Compare the feed particle size distributions in the training set and in the test set. If the distributions vary significantly, the model evaluation will be incorrect.

# %% [markdown]
# 2.3. Consider the total concentrations of all substances at different stages: raw feed, rougher concentrate, and final concentrate. Do you notice any abnormal values in the total distribution? If you do, is it worth removing such values from both samples? Describe the findings and eliminate anomalies.

# %%
metals = ['au', 'ag', 'pb']
columns = ['rougher.output.tail', 'primary_cleaner.output.tail','final.output.tail',\
           'rougher.output.concentrate', 'primary_cleaner.output.concentrate', 'final.output.concentrate']

_, axs = plt.subplots(2,3, figsize=(21, 9))
axs = axs.flatten()

for column, ax in zip(columns, axs):
    cols = [f"{t}_{m}" for t,m in zip([column]*3,metals)]
    temp_df = pd.melt(df_train[cols])
    temp_df["variable"] = temp_df["variable"].str.replace(column+"_","")
    display_group_density_plot(temp_df, groupby="variable", on="value", title=f"distribution of {column} per metals", ax=ax)
    ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# we could see that there are some abnormal values of the concentration, especially in rougher and primary_cleaner stages. assume, that when first readouts had come about a concentration of the pb, ag, and on this stage we got some outliers around zero.

# %%
metals = ['au', 'ag', 'pb']
columns = ['rougher.output.tail', 'primary_cleaner.output.tail','final.output.tail',\
           'rougher.output.concentrate', 'primary_cleaner.output.concentrate', 'final.output.concentrate']

_, axs = plt.subplots(2,3, figsize=(21, 9))
axs = axs.flatten()

for column, ax in zip(columns, axs):
    cols = [f"{t}_{m}" for t,m in zip([column]*3,metals)]
    temp_df = pd.melt(df_train[cols])
    temp_df["variable"] = temp_df["variable"].str.replace(column+"_","")
    sns.boxplot(x="variable", y="value", hue="variable", data=temp_df, ax=ax)
    ax.legend()

plt.tight_layout()
plt.show()

# %%
metals = ['au', 'ag', 'pb']
column = 'rougher.input.feed'
cols = [f"{t}_{m}" for t,m in zip([column]*3,metals)]
temp_df = pd.melt(df_train[cols])
temp_df["variable"] = temp_df["variable"].str.replace(column+"_","")
ax = display_group_density_plot(temp_df, groupby="variable", on="value", title=f"distribution of {column} per metals")
temp_df = pd.melt(df_test[cols])
temp_df["variable"] = temp_df["variable"].str.replace(column+"_","")
display_group_density_plot(temp_df, groupby="variable", on="value", title=f"distribution of {column} per metals", ax=ax)
plt.tight_layout()
plt.show()

# %%
list(filter(lambda s: "feed_size" in s, df_train.columns))
# Out:
# ['primary_cleaner.input.feed_size', 'rougher.input.feed_size']

# %%
sns.distplot(df_train["primary_cleaner.input.feed_size"],bins=15, hist_kws=dict(alpha=0.7), label="train")
g = sns.distplot(df_test["primary_cleaner.input.feed_size"],bins=15, hist_kws=dict(alpha=0.3), label="test")
g.set(xlim=(0, 20))
g.legend()

# %%
sns.distplot(df_train["rougher.input.feed_size"],bins=100, hist_kws=dict(alpha=0.7), label="train")
g = sns.distplot(df_test["rougher.input.feed_size"],bins=100, hist_kws=dict(alpha=0.3), label="test")
g.set(xlim=(0, 150))
g.legend()

# %%
df_train.describe()['rougher.input.feed_size']
# Out:
# count    14149.000000
# mean        60.239856
# std         23.005310
# min          9.659576
# 25%         48.966751
# 50%         55.269784
# 75%         66.007526
# max        484.967466
# Name: rougher.input.feed_size, dtype: float64

# %%
df_test.describe()['rougher.input.feed_size']
# Out:
# count    5290.000000
# mean       55.952754
# std        19.080334
# min         0.046369
# 25%        43.906504
# 50%        50.846843
# 75%        62.451165
# max       392.494040
# Name: rougher.input.feed_size, dtype: float64

# %% [markdown]
# #### Summary:

# %% [markdown]
# According to density plots the feed particle size distributions in the training set and in the test set is differenet, but I'd say so, it's not vary significantly, also we could see that mean values are really close to each other

# %% [markdown]
# as we could see, concentration of the gold was increased, but plumbum and silver after final stage were decreased or quite the same
# (gold's concentration is increasing in a linear way. it's seems there is some chemistry property of the plumbum,  it's not changing so much in the final stage and silver's concetration is decreasing to a final stage)

# %% [markdown]
# <div class="alert alert-success">
#     Great, you've studied the concentration changes, so we know that the process is doing what it's supposed to.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
#     1. You seem to compare "input.feed" distributions instead of "input.feed_size" distributions. <br>
#     2. Although you studied total concentrations, it seems that you missed the abnormal values near 0.
# </div>

# %% [markdown]
# > * 1. it's true, it seems that I confused;) fixed it
#   * I've noticed it, but didn't know how to explain, added explanation. also I think, that we need to leave this values for model, because it's better also to teach model on this abnormal values(on plots we could see that abnormal values near 0 are not just simple outliers)

# %% [markdown]
# 3. Build the model

# %% [markdown]
# 3.1. Write a function to calculate the final sMAPE value.

# %% [markdown]
# 3.2. Train different models. Evaluate them using cross-validation. Pick the best model and test it using the test sample. Provide findings.
# Use these formulas for evaluation metrics:
#
# $sMAPE= \frac{1}{N} \sum_{i=1}^{N} \frac {|y_i-\hat{y_i}|}{(|y_i|+|\hat{y_i}|)/2} \times 100\% $
#
# $Final\hspace{0.2cm}sMAPE = 25\% \times sMAPE(rougher) + 75\% \times sMAPE(final)$

# %%
target = ['rougher.output.recovery', 'final.output.recovery']
features = list(set(df_train.columns).intersection(set(df_test.columns)).difference(set(target)))

# %%
def smape(y_true, y_pred):
    frac = np.divide(np.abs(y_true - y_pred), (np.abs(y_true)+np.abs(y_pred))/2)
    return np.average(frac, axis=0)

# %%
def smape_final(y_true,y_pred):
    smape_out_rougher = smape(y_true[target.index('rougher.output.recovery')], y_pred[target.index('rougher.output.recovery')])
    smape_out_final = smape(y_true[target.index('final.output.recovery')], y_pred[target.index('final.output.recovery')])
    return 0.25*smape_out_rougher + 0.75*smape_out_final

# %% [markdown]
# <div class="alert alert-success">
#     Metric calculation is absolutely correct!
# </div>

# %%
print(df_train.isna().sum().sum())
print(df_test.isna().sum().sum())
# Out:
# 0
# 0

# %%
df_train = df_train.dropna()
df_test = df_test.dropna()

# %%
smape_score = make_scorer(smape_final)

# %%
X_train, X_test = df_train[features].values, df_test[features].values
y_train, y_test = df_train[target].values, df_test[target].values
display(X_train)
# Out:
# array([[-455.46298218,   23.96179771,  999.70690918, ..., -442.20446777,
#         1416.35498047, 1551.4342041 ],
#        [-450.86984762,   23.97055025, 1000.28639767, ..., -449.83064631,
#         1399.71951394, 1575.95062568],
#        [-449.93758816,   23.91353473,  999.71956517, ..., -449.95449144,
#         1400.31668194, 1600.38668535],
#        ...,
#        [-500.5056773 ,   25.94842861, 1204.86663888, ..., -500.54905279,
#          850.45563548, 1649.19690421],
#        [-499.04046576,   25.97173699, 1201.90417739, ..., -500.23733476,
#          851.34560554, 1648.21223972],
#        [-499.2555029 ,   26.03398999, 1196.23811223, ..., -500.35409056,
#          850.1122457 , 1650.13539491]])

# %%
print(X_train)
# Out:
# [[-455.46298218   23.96179771  999.70690918 ... -442.20446777
#   1416.35498047 1551.4342041 ]
#  [-450.86984762   23.97055025 1000.28639767 ... -449.83064631
#   1399.71951394 1575.95062568]
#  [-449.93758816   23.91353473  999.71956517 ... -449.95449144
#   1400.31668194 1600.38668535]
#  ...
#  [-500.5056773    25.94842861 1204.86663888 ... -500.54905279
#    850.45563548 1649.19690421]
#  [-499.04046576   25.97173699 1201.90417739 ... -500.23733476
#    851.34560554 1648.21223972]
#  [-499.2555029    26.03398999 1196.23811223 ... -500.35409056
#    850.1122457  1650.13539491]]

# %%
lr = LinearRegression().fit(X_train, y_train)
scores_lr = cross_val_score(lr, X_train, y_train, cv=5, scoring=smape_score)
print("mean smape:", scores_lr.mean())
scores_lr
# Out:
# mean smape: 0.061410217861204985
# array([0.03233747, 0.09156739, 0.09424053, 0.04954844, 0.03935726])

# %%
params = {'min_samples_split': range(2, 10, 2), 'max_depth': range(4,8,2)}
g_cv = GridSearchCV(DecisionTreeRegressor(random_state=random_state),param_grid=params,scoring=smape_score, cv=5, refit=True)
g_cv.fit(X_train, y_train)
best_params = g_cv.best_params_
print(best_params)
# Out:
# {'max_depth': 4, 'min_samples_split': 2}

# %%
dtr = DecisionTreeRegressor(**best_params).fit(X_train, y_train)
scores_dtr = cross_val_score(dtr, X_train, y_train, cv=5, scoring=smape_score)
print("mean smape:", scores_dtr.mean())
scores_dtr
# Out:
# mean smape: 0.06413835818858504
# array([0.06771186, 0.15912833, 0.01024544, 0.06642316, 0.01718302])

# %%
params = {'min_samples_split': range(2, 6, 2)}
rf_cv = GridSearchCV(RandomForestRegressor(random_state=random_state),param_grid=params,scoring=smape_score, cv=5, refit=True)
rf_cv.fit(X_train, y_train)
best_params = rf_cv.best_params_
print(best_params)
# Out:
# {'min_samples_split': 2}

# %%
rfr = RandomForestRegressor(**best_params).fit(X_train, y_train)
scores_rfr = cross_val_score(rfr, X_train, y_train, cv=5, scoring=smape_score)
print("mean smape:", scores_rfr.mean())
scores_rfr
# Out:
# mean smape: 0.12010844631680803
# array([0.21890145, 0.2803662 , 0.00640303, 0.06551011, 0.02936144])

# %% [markdown]
# let's check with our baseline - DummyRegressor

# %%
dm = DummyRegressor(strategy='mean').fit(X_train, y_train)
y_pred = dm.predict(X_test)
print('smape:', smape_final(y_test, y_pred))
# Out:
# smape: 0.05430579681049148

# %% [markdown]
# #### Summary:
#
# we compared several models with Dummy Regressor (sMAPE=0.054):
#
# 1) Linear regression: $sMAPE_{mean}\approx$0.0614
#
# 2) Decision tree regressor: $sMAPE_{mean}\approx$0.0614
#
# 3) Random forest regressor: $sMAPE_{mean}\approx$0.1087
#
# Linear regression and Decision tree regressor have the best result according to the sMAPE

# %% [markdown]
# <div class="alert alert-info">
#     The model training section is great: you try a few models, correctly use the train and test sets, use cross-validation, do some hyper-parameter tuning, and have a baseline. The only thing that is strange to me is that you say that linear regression and decision tree regressor have the best results, but don't say that they are both outperformed by a very dumb constant model predicting the mean of train set targets.
# </div>

# %% [markdown]
# >that's true;)

# %% [markdown]
# Project evaluation
# * We’ve put together the evaluation criteria for the project. Read this carefully before moving on to the case.
# * Here’s what the reviewers will look at when reviewing your project:
# * Have you prepared and analyzed the data properly?
# * What models have you developed?
# * How did you check the model‘s quality?
# * Have you followed all the steps of the instructions?
# * Did you keep to the project structure and explain the steps performed?
# * What are your findings?
# * Have you kept the code neat and avoided code duplication?
